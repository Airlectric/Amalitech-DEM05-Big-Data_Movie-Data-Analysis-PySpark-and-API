# %%
from pathlib import Path
import sys 
import pandas as pd
import json

sys.path.append(str(Path.cwd().parent))

from pyspark.sql import SparkSession
import os

# Path to log4j.properties
notebook_dir = Path().resolve()
log4j_path = log4j_path = notebook_dir.parent / "conf" / "log4j.properties"

spark = (
    SparkSession.builder
    .appName("MovieProject")
    .config("spark.driver.extraJavaOptions", f"-Dlog4j.configuration=file:{log4j_path}")
    .config("spark.executor.extraJavaOptions", f"-Dlog4j.configuration=file:{log4j_path}")
    .getOrCreate()
)

spark.sparkContext.setLogLevel("WARN") 

# %reload_ext autoreload
# %autoreload 2

import scripts.extraction.extractor_tmdb as tmdb
import scripts.transform.clean_data as cln
import scripts.transform.tmdb_data_preprocessor as dp
import scripts.transform.tmdb_schema as ts
# import analysis.kpi_analysis as kpi 
# import visualize.visualizations as viz

# %% [markdown]
# ## Fetch all movies and store in a Database

# %%
movie_ids = [0, 299534, 19995, 140607, 299536, 597, 135397, 420818, 24428, 168259, 99861, 284054, 12445, 181808, 330457, 351286, 109445, 321612, 260513]

# %%
movies = tmdb.get_all_movies_by_ids(movie_ids)
# Out:
# 2026-01-15 15:52:01,387 - INFO - extractor_tmdb - Fetching movie ID: 0
# 2026-01-15 15:52:02,041 - ERROR - extractor_tmdb - HTTP error on attempt 0: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?append_to_response=credits&api_key=d855a01d02babf081991d455eff39348&language=en-US&movie_id=0
# 2026-01-15 15:52:04,693 - ERROR - extractor_tmdb - HTTP error on attempt 1: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?append_to_response=credits&api_key=d855a01d02babf081991d455eff39348&language=en-US&movie_id=0
# 2026-01-15 15:52:07,354 - ERROR - extractor_tmdb - HTTP error on attempt 2: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?append_to_response=credits&api_key=d855a01d02babf081991d455eff39348&language=en-US&movie_id=0
# 2026-01-15 15:52:09,928 - ERROR - extractor_tmdb - HTTP error on attempt 3: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?append_to_response=credits&api_key=d855a01d02babf081991d455eff39348&language=en-US&movie_id=0
# 2026-01-15 15:52:12,390 - ERROR - extractor_tmdb - HTTP error on attempt 4: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?append_to_response=credits&api_key=d855a01d02babf081991d455eff39348&language=en-US&movie_id=0
# 2026-01-15 15:52:15,146 - ERROR - extractor_tmdb - HTTP error on attempt 5: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?append_to_response=credits&api_key=d855a01d02babf081991d455eff39348&language=en-US&movie_id=0
# 2026-01-15 15:52:15,150 - ERROR - extractor_tmdb - Failed after 5 attempts: https://api.themoviedb.org/3/movie/0?append_to_response=credits
# 2026-01-15 15:52:15,154 - ERROR - extractor_tmdb - Failed to fetch movies 0: Max retries reached.
# 2026-01-15 15:52:15,157 - WARNING - extractor_tmdb - Skipping movie ID 0 due to fetch error: Max retries reached.
# 2026-01-15 15:52:15,160 - INFO - extractor_tmdb - Fetching movie ID: 299534
# 2026-01-15 15:52:16,239 - INFO - extractor_tmdb - Fetching movie ID: 19995
# 2026-01-15 15:52:16,768 - INFO - extractor_tmdb - Fetching movie ID: 140607
# 2026-01-15 15:52:17,172 - INFO - extractor_tmdb - Fetching movie ID: 299536
# 2026-01-15 15:52:17,937 - INFO - extractor_tmdb - Fetching movie ID: 597
# 2026-01-15 15:52:18,418 - INFO - extractor_tmdb - Fetching movie ID: 135397
# 2026-01-15 15:52:19,033 - INFO - extractor_tmdb - Fetching movie ID: 420818
# 2026-01-15 15:52:19,434 - INFO - extractor_tmdb - Fetching movie ID: 24428
# 2026-01-15 15:52:20,162 - INFO - extractor_tmdb - Fetching movie ID: 168259
# 2026-01-15 15:52:20,651 - INFO - extractor_tmdb - Fetching movie ID: 99861
# 2026-01-15 15:52:21,298 - INFO - extractor_tmdb - Fetching movie ID: 284054
# 2026-01-15 15:52:21,700 - INFO - extractor_tmdb - Fetching movie ID: 12445
# 2026-01-15 15:52:22,118 - INFO - extractor_tmdb - Fetching movie ID: 181808
# 2026-01-15 15:52:22,622 - INFO - extractor_tmdb - Fetching movie ID: 330457
# 2026-01-15 15:52:23,226 - INFO - extractor_tmdb - Fetching movie ID: 351286
# 2026-01-15 15:52:23,586 - INFO - extractor_tmdb - Fetching movie ID: 109445
# 2026-01-15 15:52:24,044 - INFO - extractor_tmdb - Fetching movie ID: 321612
# 2026-01-15 15:52:24,420 - INFO - extractor_tmdb - Fetching movie ID: 260513

# %%
output_path = Path("tmdb_raw_movies.jsonl")

with output_path.open("w", encoding="utf-8") as f:
    for movie in movies:
        if movie:
            json.dump(movie, f, ensure_ascii=False)
            f.write("\n")

print(f"Saved {len(movies)} movies to {output_path}")
# Out:
# Saved 18 movies to tmdb_raw_movies.jsonl

# %%
df = spark.read \
    .option("multiLine", "true") \
    .schema(ts.data_schema) \
    .json(str(output_path))

# %%
df.printSchema()
# Out:
# root
#  |-- adult: boolean (nullable = true)
#  |-- backdrop_path: string (nullable = true)
#  |-- belongs_to_collection: struct (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- poster_path: string (nullable = true)
#  |    |-- backdrop_path: string (nullable = true)
#  |-- budget: long (nullable = true)
#  |-- genres: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: integer (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |-- homepage: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- imdb_id: string (nullable = true)
#  |-- origin_country: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- original_language: string (nullable = true)
#  |-- original_title: string (nullable = true)
#  |-- overview: string (nullable = true)
#  |-- popularity: double (nullable = true)
#  |-- poster_path: string (nullable = true)
#  |-- production_companies: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: integer (nullable = true)
#  |    |    |-- logo_path: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- origin_country: string (nullable = true)
#  |-- production_countries: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- iso_3166_1: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |-- release_date: string (nullable = true)
#  |-- revenue: long (nullable = true)
#  |-- runtime: integer (nullable = true)
#  |-- spoken_languages: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- english_name: string (nullable = true)
#  |    |    |-- iso_639_1: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- tagline: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- video: boolean (nullable = true)
#  |-- vote_average: double (nullable = true)
#  |-- vote_count: long (nullable = true)
#  |-- credits: struct (nullable = true)
#  |    |-- cast: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- adult: boolean (nullable = true)
#  |    |    |    |-- gender: integer (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- known_for_department: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- original_name: string (nullable = true)
#  |    |    |    |-- popularity: double (nullable = true)
#  |    |    |    |-- profile_path: string (nullable = true)
#  |    |    |    |-- cast_id: integer (nullable = true)
#  |    |    |    |-- character: string (nullable = true)
#  |    |    |    |-- credit_id: string (nullable = true)
#  |    |    |    |-- order: integer (nullable = true)
#  |    |-- crew: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- adult: boolean (nullable = true)
#  |    |    |    |-- gender: integer (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- known_for_department: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- original_name: string (nullable = true)
#  |    |    |    |-- popularity: double (nullable = true)
#  |    |    |    |-- profile_path: string (nullable = true)
#  |    |    |    |-- credit_id: string (nullable = true)
#  |    |    |    |-- department: string (nullable = true)
#  |    |    |    |-- job: string (nullable = true)

# %%
categorical_columns = ['belongs_to_collection', 'genres', 'production_countries', 'production_companies', 'spoken_languages', 'origin_country',"credits.cast", "credits.crew"]

# %%
df.select(*categorical_columns).show(3, truncate=100, vertical=True)
# Out:
# -RECORD 0---------------------------------------------------------------------------------------------------------------------
#  belongs_to_collection | {86311, The Avengers Collection, /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg, /zuW6fOiusv4X9nnW3paHGfXcSll.jpg}
#  genres                | [{12, Adventure}, {878, Science Fiction}, {28, Action}]
#  production_countries  | [{US, United States of America}]
#  production_companies  | [{420, /hUzeosd33nzE5MCNsZxCGEKTXaQ.png, Marvel Studios, US}]
#  spoken_languages      | [{English, en, English}, {Japanese, ja, 日本語}, {Xhosa, xh, }]
#  origin_country        | [US]
#  cast                  | [{false, 2, 3223, Acting, Robert Downey Jr., Robert Downey Jr., 9.8254, /5qHNjhtjMD4YWH3UP0rm4tKw...
#  crew                  | [{false, 0, 3019687, Directing, Paul Schneider, Paul Schneider, 0.2165, NULL, 6057fbdf8c44b900546...

# %%
df.limit(10).toPandas()
# Out:
#    adult                     backdrop_path  \
# 0  False  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg
#
#                                belongs_to_collection     budget  \
# 0  (86311, The Avengers Collection, /yFSIUVTCvgYr...  356000000
#
#                                               genres  \
# 0  [(12, Adventure), (878, Science Fiction), (28,...
#
#                                          homepage      id    imdb_id  \
# 0  https://www.marvel.com/movies/avengers-endgame  299534  tt4154796
#
#   origin_country original_language  ...     revenue runtime  \
# 0           [US]                en  ...  2799439100     181
#
#                                     spoken_languages    status  \
# 0  [(English, en, English), (Japanese, ja, 日本語), ...  Released
#
#               tagline              title  video  vote_average  vote_count  \
# 0  Avenge the fallen.  Avengers: Endgame  False         8.238       27125
#
#                                              credits
# 0  ([(False, 2, 3223, Acting, Robert Downey Jr., ...
#
# [1 rows x 27 columns]

# %%
df.columns
# Out:
# ['adult',
#  'backdrop_path',
#  'belongs_to_collection',
#  'budget',
#  'credits',
#  'genres',
#  'homepage',
#  'id',
#  'imdb_id',
#  'origin_country',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'revenue',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'video',
#  'vote_average',
#  'vote_count']

# %% [markdown]
# ## Drop irrelevant columns

# %%
cols_to_drop = ['adult', 'imdb_id', 'original_title', 'video', 'homepage', 	'success', 'status_code', 'status_message']
df = cln.drop_irrelevant_columns(df, cols_to_drop)
# Out:
# 2026-01-15 14:09:51,607 - INFO - clean_data - Dropping columns: ['adult', 'imdb_id', 'original_title', 'video', 'homepage', 'success', 'status_code', 'status_message']

# %%
df.toPandas()
# Out:
#                        backdrop_path  \
# 0   /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg
# 1   /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg
# 2   /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg
# 3   /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg
# 4   /xnHVX37XZEp33hhCbYlQFq7ux1J.jpg
# 5   /s5QfDFqRO6sjgPtKkjxD0WqXQef.jpg
# 6   /1TUg5pO1VZ4B0Q1amk3OlXvlpXV.jpg
# 7   /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 8   /ehzI1mVcnHqB58NqPyQwpMqcVoz.jpg
# 9   /kIBK5SKwgqIIuRKhhWrJn3XkbPq.jpg
# 10  /19Ed4XgjahPm4U8JT7SnntERIlt.jpg
# 11  /cbcpDn6XJaIGoOil1bKuskU8ds4.jpg
# 12  /5Iw7zQTHVRBOYpA0V6z0yypOPZh.jpg
# 13  /AoSZyb37ljMAxw0RdeQEBHKtgcc.jpg
# 14  /6WA9stUMbIkEPxn3D5SWlA8FIi7.jpg
# 15  /9WHM084AoskcHCObAy4QnJg01eM.jpg
# 16  /uU1Mt4JWhDvl4vKb3AfxNsorkoM.jpg
# 17  /mabuNsGJgRuCTuGqjFkWe1xdu19.jpg
#
#                                 belongs_to_collection     budget  \
# 0   {'backdrop_path': None, 'name': None, 'id': 86...  356000000
# 1   {'backdrop_path': None, 'name': None, 'id': 87...  237000000
# 2   {'backdrop_path': None, 'name': None, 'id': 10...  245000000
# 3   {'backdrop_path': None, 'name': None, 'id': 86...  300000000
# 4                                                None  200000000
# 5   {'backdrop_path': None, 'name': None, 'id': 32...  150000000
# 6   {'backdrop_path': None, 'name': None, 'id': 76...  260000000
# 7   {'backdrop_path': None, 'name': None, 'id': 86...  220000000
# 8   {'backdrop_path': None, 'name': None, 'id': 94...  190000000
# 9   {'backdrop_path': None, 'name': None, 'id': 86...  235000000
# 10  {'backdrop_path': None, 'name': None, 'id': 52...  200000000
# 11  {'backdrop_path': None, 'name': None, 'id': 12...  125000000
# 12  {'backdrop_path': None, 'name': None, 'id': 10...  300000000
# 13  {'backdrop_path': None, 'name': None, 'id': 38...  150000000
# 14  {'backdrop_path': None, 'name': None, 'id': 32...  170000000
# 15  {'backdrop_path': None, 'name': None, 'id': 38...  150000000
# 16                                               None  160000000
# 17  {'backdrop_path': None, 'name': None, 'id': 46...  200000000
#
#                                               credits  \
# 0   {'cast': [{'cast_id': None, 'character': None,...
# 1   {'cast': [{'cast_id': None, 'character': None,...
# 2   {'cast': [{'cast_id': None, 'character': None,...
# 3   {'cast': [{'cast_id': None, 'character': None,...
# 4   {'cast': [{'cast_id': None, 'character': None,...
# 5   {'cast': [{'cast_id': None, 'character': None,...
# 6   {'cast': [{'cast_id': None, 'character': None,...
# 7   {'cast': [{'cast_id': None, 'character': None,...
# 8   {'cast': [{'cast_id': None, 'character': None,...
# 9   {'cast': [{'cast_id': None, 'character': None,...
# 10  {'cast': [{'cast_id': None, 'character': None,...
# 11  {'cast': [{'cast_id': None, 'character': None,...
# 12  {'cast': [{'cast_id': None, 'character': None,...
# 13  {'cast': [{'cast_id': None, 'character': None,...
# 14  {'cast': [{'cast_id': None, 'character': None,...
# 15  {'cast': [{'cast_id': None, 'character': None,...
# 16  {'cast': [{'cast_id': None, 'character': None,...
# 17  {'cast': [{'cast_id': None, 'character': None,...
#
#                                                genres      id origin_country  \
# 0   [{'name': None, 'id': 12}, {'name': None, 'id'...  299534           [US]
# 1   [{'name': None, 'id': 28}, {'name': None, 'id'...   19995           [US]
# 2   [{'name': None, 'id': 12}, {'name': None, 'id'...  140607           [US]
# 3   [{'name': None, 'id': 12}, {'name': None, 'id'...  299536           [US]
# 4   [{'name': None, 'id': 18}, {'name': None, 'id'...     597           [US]
# 5   [{'name': None, 'id': 28}, {'name': None, 'id'...  135397           [US]
# 6   [{'name': None, 'id': 12}, {'name': None, 'id'...  420818           [US]
# 7   [{'name': None, 'id': 878}, {'name': None, 'id...   24428           [US]
# 8   [{'name': None, 'id': 28}, {'name': None, 'id'...  168259           [US]
# 9   [{'name': None, 'id': 28}, {'name': None, 'id'...   99861           [US]
# 10  [{'name': None, 'id': 28}, {'name': None, 'id'...  284054           [US]
# 11  [{'name': None, 'id': 12}, {'name': None, 'id'...   12445           [GB]
# 12  [{'name': None, 'id': 12}, {'name': None, 'id'...  181808           [US]
# 13  [{'name': None, 'id': 10751}, {'name': None, '...  330457           [US]
# 14  [{'name': None, 'id': 28}, {'name': None, 'id'...  351286           [US]
# 15  [{'name': None, 'id': 16}, {'name': None, 'id'...  109445           [US]
# 16  [{'name': None, 'id': 10751}, {'name': None, '...  321612           [US]
# 17  [{'name': None, 'id': 28}, {'name': None, 'id'...  260513           [US]
#
#    original_language                                           overview  \
# 0                 en  After the devastating events of Avengers: Infi...
# 1                 en  In the 22nd century, a paraplegic Marine is di...
# 2                 en  Thirty years after defeating the Galactic Empi...
# 3                 en  As the Avengers and their allies have continue...
# 4                 en  101-year-old Rose DeWitt Bukater tells the sto...
# 5                 en  Twenty-two years after the events of Jurassic ...
# 6                 en  Simba idolizes his father, King Mufasa, and ta...
# 7                 en  When an unexpected enemy emerges and threatens...
# 8                 en  Deckard Shaw seeks revenge against Dominic Tor...
# 9                 en  When Tony Stark tries to jumpstart a dormant p...
# 10                en  King T'Challa returns home to the reclusive, t...
# 11                en  Harry, Ron and Hermione continue their quest t...
# 12                en  Rey develops her newly discovered abilities wi...
# 13                en  Elsa, Anna, Kristoff and Olaf head far into th...
# 14                en  Three years after Jurassic World was destroyed...
# 15                en  Young princess Anna of Arendelle dreams about ...
# 16                en  A live-action adaptation of Disney's version o...
# 17                en  Elastigirl springs into action to save the day...
#
#     popularity  ...                               production_countries  \
# 0      20.3653  ...  [{'name': 'United States of America', 'iso_316...
# 1      64.1270  ...  [{'name': 'United States of America', 'iso_316...
# 2      10.5940  ...  [{'name': 'United States of America', 'iso_316...
# 3      29.5184  ...  [{'name': 'United States of America', 'iso_316...
# 4      30.7388  ...  [{'name': 'United States of America', 'iso_316...
# 5      10.1956  ...  [{'name': 'United States of America', 'iso_316...
# 6       9.8459  ...  [{'name': 'United States of America', 'iso_316...
# 7      69.3044  ...  [{'name': 'United States of America', 'iso_316...
# 8      10.4935  ...  [{'name': 'United States of America', 'iso_316...
# 9      16.1802  ...  [{'name': 'United States of America', 'iso_316...
# 10     11.4760  ...  [{'name': 'United States of America', 'iso_316...
# 11     17.6463  ...  [{'name': 'United Kingdom', 'iso_3166_1': 'GB'...
# 12      9.4085  ...  [{'name': 'United States of America', 'iso_316...
# 13     10.5067  ...  [{'name': 'United States of America', 'iso_316...
# 14      9.7109  ...  [{'name': 'United States of America', 'iso_316...
# 15     17.6470  ...  [{'name': 'United States of America', 'iso_316...
# 16     14.6034  ...  [{'name': 'United States of America', 'iso_316...
# 17      7.2323  ...  [{'name': 'United States of America', 'iso_316...
#
#    release_date     revenue runtime  \
# 0    2019-04-24  2799439100     181
# 1    2009-12-16  2923706026     162
# 2    2015-12-15  2068223624     136
# 3    2018-04-25  2052415039     149
# 4    1997-12-18  2264162353     194
# 5    2015-06-06  1671537444     124
# 6    2019-07-12  1662020819     118
# 7    2012-04-25  1518815515     143
# 8    2015-04-01  1515400000     139
# 9    2015-04-22  1405403694     141
# 10   2018-02-13  1349926083     135
# 11   2011-07-12  1341511219     130
# 12   2017-12-13  1332698830     152
# 13   2019-11-20  1453683476     103
# 14   2018-06-06  1310469037     129
# 15   2013-11-20  1274219009     102
# 16   2017-03-16  1266115964     129
# 17   2018-06-14  1243225667     118
#
#                                      spoken_languages    status  \
# 0   [{'name': 'English', 'iso_639_1': 'en', 'engli...  Released
# 1   [{'name': 'English', 'iso_639_1': 'en', 'engli...  Released
# 2   [{'name': 'English', 'iso_639_1': 'en', 'engli...  Released
# 3   [{'name': 'English', 'iso_639_1': 'en', 'engli...  Released
# 4   [{'name': 'English', 'iso_639_1': 'en', 'engli...  Released
# 5   [{'name': 'English', 'iso_639_1': 'en', 'engli...  Released
# 6   [{'name': 'English', 'iso_639_1': 'en', 'engli...  Released
# 7   [{'name': 'English', 'iso_639_1': 'en', 'engli...  Released
# 8   [{'name': 'العربية', 'iso_639_1': 'ar', 'engli...  Released
# 9   [{'name': 'English', 'iso_639_1': 'en', 'engli...  Released
# 10  [{'name': 'English', 'iso_639_1': 'en', 'engli...  Released
# 11  [{'name': 'English', 'iso_639_1': 'en', 'engli...  Released
# 12  [{'name': 'English', 'iso_639_1': 'en', 'engli...  Released
# 13  [{'name': 'English', 'iso_639_1': 'en', 'engli...  Released
# 14  [{'name': 'English', 'iso_639_1': 'en', 'engli...  Released
# 15  [{'name': 'English', 'iso_639_1': 'en', 'engli...  Released
# 16  [{'name': 'Français', 'iso_639_1': 'fr', 'engl...  Released
# 17  [{'name': 'English', 'iso_639_1': 'en', 'engli...  Released
#
#                                               tagline  \
# 0                                  Avenge the fallen.
# 1                         Enter the world of Pandora.
# 2                       Every generation has a story.
# 3                       Destiny arrives all the same.
# 4           Nothing on earth could come between them.
# 5                                   The park is open.
# 6                              The king has returned.
# 7                             Some assembly required.
# 8                                Vengeance hits home.
# 9                                 A new age has come.
# 10                                Long live the king.
# 11                                       It all ends.
# 12                                  Let the past die.
# 13                     The past is not what it seems.
# 14                                  The park is gone.
# 15  Who will save the day? The ice guy? The nice g...
# 16                                      Be our guest.
# 17                      It's been too long, dahlings.
#
#                                            title vote_average vote_count
# 0                              Avengers: Endgame        8.238      27125
# 1                                         Avatar        7.600      33240
# 2                   Star Wars: The Force Awakens        7.254      20198
# 3                         Avengers: Infinity War        8.235      31335
# 4                                        Titanic        7.903      26659
# 5                                 Jurassic World        6.700      21216
# 6                                  The Lion King        7.099      10602
# 7                                   The Avengers        7.904      35071
# 8                                      Furious 7        7.219      11089
# 9                        Avengers: Age of Ultron        7.271      24002
# 10                                 Black Panther        7.365      23075
# 11  Harry Potter and the Deathly Hallows: Part 2        8.083      21570
# 12                      Star Wars: The Last Jedi        6.762      16017
# 13                                     Frozen II        7.238      10119
# 14                Jurassic World: Fallen Kingdom        6.500      12481
# 15                                        Frozen        7.248      17273
# 16                          Beauty and the Beast        7.000      15875
# 17                                 Incredibles 2        7.454      13442
#
# [18 rows x 22 columns]

# %%
df.columns
# Out:
# ['backdrop_path',
#  'belongs_to_collection',
#  'budget',
#  'credits',
#  'genres',
#  'id',
#  'origin_country',
#  'original_language',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'revenue',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'vote_average',
#  'vote_count']

# %%
from pyspark.sql import functions as F

# Extract example for 'belongs_to_collection' (expecting a struct/map)
df.select("belongs_to_collection").filter(F.col("belongs_to_collection").isNotNull()).limit(1).show(truncate=False)

# Extract example for 'genres' (array of structs)
df.select("genres").filter(F.size("genres") > 0).limit(1).show(truncate=False, vertical=True)

# Extract example for 'production_countries' (array of structs)
df.select("production_countries").filter(F.size("production_countries") > 0).limit(1).show(truncate=False, vertical=True)

# Extract example for 'production_companies' (array of structs)
df.select("production_companies").filter(F.size("production_companies") > 0).limit(1).show(truncate=False, vertical=True)

# Extract example for 'spoken_languages' (array of structs)
df.select("spoken_languages").filter(F.size("spoken_languages") > 0).limit(1).show(truncate=False, vertical=True)

# Extract example for 'origin_country' (array of strings)
df.select("origin_country").filter(F.size("origin_country") > 0).limit(1).show(truncate=False)

# Extract example for 'credits' (struct with cast and crew arrays)
# df.select("credits").filter(F.col("credits").isNotNull()).limit(1).show(truncate=False, vertical=True)
# Out:
# +-----------------------------------------------------------------------+
# |belongs_to_collection                                                  |
# +-----------------------------------------------------------------------+
# |{backdrop_path -> NULL, name -> NULL, id -> 86311, poster_path -> NULL}|
# +-----------------------------------------------------------------------+
#
# -RECORD 0---------------------------------------------------------------------------------
#  genres | [{name -> NULL, id -> 12}, {name -> NULL, id -> 878}, {name -> NULL, id -> 28}]
#
# -RECORD 0----------------------------------------------------------------------
#  production_countries | [{name -> United States of America, iso_3166_1 -> US}]
#
# -RECORD 0--------------------------------------------------------------------------------------
#  production_companies | [{name -> NULL, id -> 420, logo_path -> NULL, origin_country -> NULL}]
#
# -RECORD 0------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  spoken_languages | [{name -> English, iso_639_1 -> en, english_name -> English}, {name -> 日本語, iso_639_1 -> ja, english_name -> Japanese}, {name -> , iso_639_1 -> xh, english_name -> Xhosa}]
#
# +--------------+
# |origin_country|
# +--------------+
# |[US]          |
# +--------------+

# %% [markdown]
# ## Evaluate JSON-like columns

# %%
categorical_columns = ['belongs_to_collection', 'genres', 'production_countries', 'production_companies', 'spoken_languages', 'origin_country','credits']

# %%
df.select(*categorical_columns).limit(10).toPandas()
# Out:
#                                belongs_to_collection  \
# 0  {'backdrop_path': None, 'name': None, 'id': 86...
# 1  {'backdrop_path': None, 'name': None, 'id': 87...
# 2  {'backdrop_path': None, 'name': None, 'id': 10...
# 3  {'backdrop_path': None, 'name': None, 'id': 86...
# 4                                               None
# 5  {'backdrop_path': None, 'name': None, 'id': 32...
# 6  {'backdrop_path': None, 'name': None, 'id': 76...
# 7  {'backdrop_path': None, 'name': None, 'id': 86...
# 8  {'backdrop_path': None, 'name': None, 'id': 94...
# 9  {'backdrop_path': None, 'name': None, 'id': 86...
#
#                                               genres  \
# 0  [{'name': None, 'id': 12}, {'name': None, 'id'...
# 1  [{'name': None, 'id': 28}, {'name': None, 'id'...
# 2  [{'name': None, 'id': 12}, {'name': None, 'id'...
# 3  [{'name': None, 'id': 12}, {'name': None, 'id'...
# 4  [{'name': None, 'id': 18}, {'name': None, 'id'...
# 5  [{'name': None, 'id': 28}, {'name': None, 'id'...
# 6  [{'name': None, 'id': 12}, {'name': None, 'id'...
# 7  [{'name': None, 'id': 878}, {'name': None, 'id...
# 8  [{'name': None, 'id': 28}, {'name': None, 'id'...
# 9  [{'name': None, 'id': 28}, {'name': None, 'id'...
#
#                                 production_countries  \
# 0  [{'name': 'United States of America', 'iso_316...
# 1  [{'name': 'United States of America', 'iso_316...
# 2  [{'name': 'United States of America', 'iso_316...
# 3  [{'name': 'United States of America', 'iso_316...
# 4  [{'name': 'United States of America', 'iso_316...
# 5  [{'name': 'United States of America', 'iso_316...
# 6  [{'name': 'United States of America', 'iso_316...
# 7  [{'name': 'United States of America', 'iso_316...
# 8  [{'name': 'United States of America', 'iso_316...
# 9  [{'name': 'United States of America', 'iso_316...
#
#                                 production_companies  \
# 0  [{'name': None, 'id': 420, 'logo_path': None, ...
# 1  [{'name': None, 'id': 444, 'logo_path': None, ...
# 2  [{'name': None, 'id': 1, 'logo_path': None, 'o...
# 3  [{'name': None, 'id': 420, 'logo_path': None, ...
# 4  [{'name': None, 'id': 4, 'logo_path': None, 'o...
# 5  [{'name': None, 'id': 56, 'logo_path': None, '...
# 6  [{'name': None, 'id': 2, 'logo_path': None, 'o...
# 7  [{'name': None, 'id': 420, 'logo_path': None, ...
# 8  [{'name': None, 'id': 333, 'logo_path': None, ...
# 9  [{'name': None, 'id': 420, 'logo_path': None, ...
#
#                                     spoken_languages origin_country  \
# 0  [{'name': 'English', 'iso_639_1': 'en', 'engli...           [US]
# 1  [{'name': 'English', 'iso_639_1': 'en', 'engli...           [US]
# 2  [{'name': 'English', 'iso_639_1': 'en', 'engli...           [US]
# 3  [{'name': 'English', 'iso_639_1': 'en', 'engli...           [US]
# 4  [{'name': 'English', 'iso_639_1': 'en', 'engli...           [US]
# 5  [{'name': 'English', 'iso_639_1': 'en', 'engli...           [US]
# 6  [{'name': 'English', 'iso_639_1': 'en', 'engli...           [US]
# 7  [{'name': 'English', 'iso_639_1': 'en', 'engli...           [US]
# 8  [{'name': 'العربية', 'iso_639_1': 'ar', 'engli...           [US]
# 9  [{'name': 'English', 'iso_639_1': 'en', 'engli...           [US]
#
#                                              credits
# 0  {'cast': [{'cast_id': None, 'character': None,...
# 1  {'cast': [{'cast_id': None, 'character': None,...
# 2  {'cast': [{'cast_id': None, 'character': None,...
# 3  {'cast': [{'cast_id': None, 'character': None,...
# 4  {'cast': [{'cast_id': None, 'character': None,...
# 5  {'cast': [{'cast_id': None, 'character': None,...
# 6  {'cast': [{'cast_id': None, 'character': None,...
# 7  {'cast': [{'cast_id': None, 'character': None,...
# 8  {'cast': [{'cast_id': None, 'character': None,...
# 9  {'cast': [{'cast_id': None, 'character': None,...

# %% [markdown]
# ## Extracting and cleaning json columns

# %%
df = cln.clean_movie_data(df)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df = cln.clean_movie_data(df)
#
# File /workspace/scripts/transform/clean_data.py:156, in clean_movie_data(movies_df)
#     147 json_columns = {
#     148     "belongs_to_collection": "name",
#     149     "genres": "name",
#    (...)
#     152     "production_countries": "name",
#     153 }
#     155 for col, key in json_columns.items():
# --> 156     movies_df = extract_json_field(movies_df, col, key)
#     158 movies_df = extract_production_countries(
#     159     movies_df, col="origin_country"
#     160 )
#     162 movies_df = extract_credit_json_fields(
#     163     movies_df, col="credits"
#     164 )
#
# File /workspace/scripts/transform/clean_data.py:27, in extract_json_field(df, col, key, join_with)
#      16 def extract_json_field(
#      17     df: DataFrame,
#      18     col: str,
#      19     key: str,
#      20     join_with: str = "|"
#      21 ) -> DataFrame:
#      22     """
#      23     - map -> extract value by key
#      24     - array<map> -> extract key from each element and join
#      25     """
# ---> 27     return df.withColumn(
#      28         col,
#      29         F.when(
#      30             F.col(col).isNull(),
#      31             F.lit(None)
#      32         )
#      33         # array<map>
#      34         .when(
#      35             F.expr(f"typeof({col}) LIKE 'array%'"),
#      36             F.concat_ws(
#      37                 join_with,
#      38                 F.expr(f"transform({col}, x -> x['{key}'])")
#      39             )
#      40         )
#      41         # map
#      42         .otherwise(F.col(col)[key])
#      43     )
#
# File /usr/local/lib/python3.8/dist-packages/pyspark/sql/dataframe.py:5176, in DataFrame.withColumn(self, colName, col)
#    5171 if not isinstance(col, Column):
#    5172     raise PySparkTypeError(
#    5173         error_class="NOT_COLUMN",
#    5174         message_parameters={"arg_name": "col", "arg_type": type(col).__name__},
#    5175     )
# -> 5176 return DataFrame(self._jdf.withColumn(colName, col._jc), self.sparkSession)
#
# File /usr/local/lib/python3.8/dist-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /usr/local/lib/python3.8/dist-packages/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [DATATYPE_MISMATCH.UNEXPECTED_INPUT_TYPE] Cannot resolve "transform(belongs_to_collection, lambdafunction(x[name], x))" due to data type mismatch: Parameter 1 requires the "ARRAY" type, however "belongs_to_collection" has the type "MAP<STRING, BIGINT>".; line 1 pos 0;
# 'Project [backdrop_path#1, CASE WHEN isnull(belongs_to_collection#2) THEN null WHEN typeof(belongs_to_collection#2) LIKE array% THEN concat_ws(|, transform(belongs_to_collection#2, lambdafunction(lambda 'x[name], lambda 'x, false))) ELSE belongs_to_collection#2[name] END AS belongs_to_collection#235, budget#3L, credits#4, genres#5, id#7L, origin_country#9, original_language#10, overview#12, popularity#13, poster_path#14, production_companies#15, production_countries#16, release_date#17, revenue#18L, runtime#19L, spoken_languages#20, status#21, tagline#22, title#23, vote_average#25, vote_count#26L]
# +- Project [backdrop_path#1, belongs_to_collection#2, budget#3L, credits#4, genres#5, id#7L, origin_country#9, original_language#10, overview#12, popularity#13, poster_path#14, production_companies#15, production_countries#16, release_date#17, revenue#18L, runtime#19L, spoken_languages#20, status#21, tagline#22, title#23, vote_average#25, vote_count#26L]
#    +- LogicalRDD [adult#0, backdrop_path#1, belongs_to_collection#2, budget#3L, credits#4, genres#5, homepage#6, id#7L, imdb_id#8, origin_country#9, original_language#10, original_title#11, overview#12, popularity#13, poster_path#14, production_companies#15, production_countries#16, release_date#17, revenue#18L, runtime#19L, spoken_languages#20, status#21, tagline#22, title#23, ... 3 more fields], false

# %%
df.limit(10).toPandas()
# Out:
#                       backdrop_path belongs_to_collection       budget genres  \
# 0  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg                  None  356000000.0   None
# 1  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg                  None  237000000.0   None
# 2  /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg                  None  245000000.0   None
# 3  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg                  None  300000000.0   None
# 4  /xnHVX37XZEp33hhCbYlQFq7ux1J.jpg                  None  200000000.0   None
# 5  /s5QfDFqRO6sjgPtKkjxD0WqXQef.jpg                  None  150000000.0   None
# 6  /1TUg5pO1VZ4B0Q1amk3OlXvlpXV.jpg                  None  260000000.0   None
# 7  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg                  None  220000000.0   None
# 8  /ehzI1mVcnHqB58NqPyQwpMqcVoz.jpg                  None  190000000.0   None
# 9  /kIBK5SKwgqIIuRKhhWrJn3XkbPq.jpg                  None  235000000.0   None
#
#          id origin_country original_language  \
# 0  299534.0             US                en
# 1   19995.0             US                en
# 2  140607.0             US                en
# 3  299536.0             US                en
# 4     597.0             US                en
# 5  135397.0             US                en
# 6  420818.0             US                en
# 7   24428.0             US                en
# 8  168259.0             US                en
# 9   99861.0             US                en
#
#                                             overview  popularity  \
# 0  After the devastating events of Avengers: Infi...     20.3653
# 1  In the 22nd century, a paraplegic Marine is di...     64.1270
# 2  Thirty years after defeating the Galactic Empi...     10.5940
# 3  As the Avengers and their allies have continue...     29.5184
# 4  101-year-old Rose DeWitt Bukater tells the sto...     30.7388
# 5  Twenty-two years after the events of Jurassic ...     10.1956
# 6  Simba idolizes his father, King Mufasa, and ta...      9.8459
# 7  When an unexpected enemy emerges and threatens...     69.3044
# 8  Deckard Shaw seeks revenge against Dominic Tor...     10.4935
# 9  When Tony Stark tries to jumpstart a dormant p...     16.1802
#
#                         poster_path  ... spoken_languages    status  \
# 0  /bR8ISy1O9XQxqiy0fQFw2BX72RQ.jpg  ...             None  Released
# 1  /gKY6q7SjCkAU6FqvqWybDYgUKIF.jpg  ...             None  Released
# 2  /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg  ...             None  Released
# 3  /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg  ...             None  Released
# 4  /9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg  ...             None  Released
# 5  /rhr4y79GpxQF9IsfJItRXVaoGs4.jpg  ...             None  Released
# 6  /dzBtMocZuJbjLOXvrl4zGYigDzh.jpg  ...             None  Released
# 7   /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg  ...             None  Released
# 8  /ktofZ9Htrjiy0P6LEowsDaxd3Ri.jpg  ...             None  Released
# 9  /4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg  ...             None  Released
#
#                                      tagline                         title  \
# 0                         Avenge the fallen.             Avengers: Endgame
# 1                Enter the world of Pandora.                        Avatar
# 2              Every generation has a story.  Star Wars: The Force Awakens
# 3              Destiny arrives all the same.        Avengers: Infinity War
# 4  Nothing on earth could come between them.                       Titanic
# 5                          The park is open.                Jurassic World
# 6                     The king has returned.                 The Lion King
# 7                    Some assembly required.                  The Avengers
# 8                       Vengeance hits home.                     Furious 7
# 9                        A new age has come.       Avengers: Age of Ultron
#
#    vote_average vote_count                                               cast  \
# 0         8.238    27125.0  ||||||||||||||||||||||||||||||||||||||||||||||...
# 1         7.600    33240.0  ||||||||||||||||||||||||||||||||||||||||||||||...
# 2         7.254    20198.0  ||||||||||||||||||||||||||||||||||||||||||||||...
# 3         8.235    31335.0  ||||||||||||||||||||||||||||||||||||||||||||||...
# 4         7.903    26659.0  ||||||||||||||||||||||||||||||||||||||||||||||...
# 5         6.700    21216.0  ||||||||||||||||||||||||||||||||||||||||||||||...
# 6         7.099    10602.0                                |||||||||||||||||||
# 7         7.904    35071.0  ||||||||||||||||||||||||||||||||||||||||||||||...
# 8         7.219    11089.0   ||||||||||||||||||||||||||||||||||||||||||||||||
# 9         7.271    24002.0  ||||||||||||||||||||||||||||||||||||||||||||||...
#
#   cast_size director  crew_size
# 0       107                 608
# 1        67                 991
# 2       183                 264
# 3        69                 734
# 4       116                 262
# 5        53                 428
# 6        20                  50
# 7       113                 642
# 8        49                 228
# 9        74                 653
#
# [10 rows x 25 columns]

# %%
df.dtypes
# Out:
# [('backdrop_path', 'string'),
#  ('belongs_to_collection', 'void'),
#  ('budget', 'double'),
#  ('genres', 'void'),
#  ('id', 'double'),
#  ('origin_country', 'string'),
#  ('original_language', 'string'),
#  ('overview', 'string'),
#  ('popularity', 'double'),
#  ('poster_path', 'string'),
#  ('production_companies', 'void'),
#  ('production_countries', 'array<map<string,string>>'),
#  ('release_date', 'date'),
#  ('revenue', 'double'),
#  ('runtime', 'double'),
#  ('spoken_languages', 'void'),
#  ('status', 'string'),
#  ('tagline', 'string'),
#  ('title', 'string'),
#  ('vote_average', 'double'),
#  ('vote_count', 'double'),
#  ('cast', 'string'),
#  ('cast_size', 'int'),
#  ('director', 'string'),
#  ('crew_size', 'int')]

# %%
from pyspark.sql import functions as F
from pyspark.sql import types as T
from pyspark.sql import DataFrame

# ---------------------------------------------------------------------------
# 1) Quick schema overview
# ---------------------------------------------------------------------------
def show_schema_overview(df: DataFrame):
    """
    Prints column name, spark type (simpleString) and whether it's nested (Array/Map/Struct).
    """
    print("Column | SparkType | Nested?")
    for f in df.schema.fields:
        t = f.dataType
        nested = any(isinstance(t, ty) for ty in (T.ArrayType, T.MapType, T.StructType))
        print(f"{f.name} | {t.simpleString()} | {nested}")


# ---------------------------------------------------------------------------
# 2) Suggest recommended extractor (based on schema)
# ---------------------------------------------------------------------------
def suggest_extractors(df: DataFrame):
    """
    For each column, suggests whether to treat it as:
     - map -> use map extractor (col.getItem(key))
     - array<map> -> transform + concat_ws on x['key']
     - array<string> -> concat_ws
     - struct -> dot-access
     - scalar -> leave as-is
    Uses df.schema so analysis-time errors are avoided.
    """
    suggestions = {}
    for f in df.schema.fields:
        t = f.dataType
        if isinstance(t, T.MapType):
            suggestions[f.name] = "MAP -> use col.getItem(key) or explode(map_entries(col))"
        elif isinstance(t, T.ArrayType):
            if isinstance(t.elementType, T.MapType):
                suggestions[f.name] = "ARRAY<MAP> -> explode/transform then extract map keys (x['name'])"
            elif isinstance(t.elementType, T.StructType):
                suggestions[f.name] = "ARRAY<STRUCT> -> explode then access struct fields (e.g. e.name)"
            elif isinstance(t.elementType, T.StringType):
                suggestions[f.name] = "ARRAY<STRING> -> concat_ws(join_with, col)"
            else:
                suggestions[f.name] = f"ARRAY<{t.elementType.simpleString()}> -> inspect elements"
        elif isinstance(t, T.StructType):
            suggestions[f.name] = "STRUCT -> use dot access (col.field)"
        else:
            suggestions[f.name] = "SCALAR -> leave or cast"
    # print pretty
    for c, s in suggestions.items():
        print(f"{c:30} : {s}")
    return suggestions


# ---------------------------------------------------------------------------
# 3) Explore a MAP column: keys, key counts, sample values (safe, distributed)
# ---------------------------------------------------------------------------
def explore_map_column(df: DataFrame, col: str, top_n: int = 20):
    """
    - counts distinct keys in the map across dataset (explodes map_keys)
    - shows top-n keys by frequency
    - shows sample values for a requested key (by exploding map_entries)
    """
    print(f"Exploring MAP column '{col}'")
    # count rows where map is non-null
    non_null = df.filter(F.col(col).isNotNull()).count()
    print(f"Non-null rows: {non_null}")

    # top keys (explode map_keys)
    keys = (
        df
        .select(F.explode(F.map_keys(F.col(col))).alias("key"))
        .groupBy("key")
        .count()
        .orderBy(F.desc("count"))
    )
    print("Top keys (key, count):")
    keys.show(top_n, truncate=False)

    # sample map entries: key + typeof(value)
    entries = (
        df
        .select(F.explode(F.map_entries(F.col(col))).alias("entry"))
        .select(F.col("entry.key").alias("key"), F.col("entry.value").alias("value"))
        .withColumn("value_type", F.typeof(F.col("value")))
        .groupBy("key", "value_type")
        .agg(F.count("*").alias("count"))
        .orderBy(F.desc("count"))
    )
    print("Key + observed value types + counts:")
    entries.show(top_n, truncate=False)

    # show some example map rows (limit)
    print("Sample raw map (first 5 non-null rows):")
    df.select(col).where(F.col(col).isNotNull()).limit(5).show(truncate=False)


# ---------------------------------------------------------------------------
# 4) Explore an ARRAY<MAP> or ARRAY<STRUCT> column
# ---------------------------------------------------------------------------
def explore_array_column(df: DataFrame, col: str, top_n: int = 20):
    """
    Explode the array and inspect element shape:
    - element typeof (map/struct/string/...)
    - if map -> map_keys and map_entries summary
    - if struct -> struct fields and a sample row
    - safe for large datasets (uses limited aggregates)
    """
    print(f"Exploring ARRAY column '{col}'")
    non_null = df.filter(F.col(col).isNotNull()).count()
    print(f"Non-null rows: {non_null}")

    # explode and get typeof for elements
    exploded = df.select(F.explode(F.col(col)).alias("elem"))
    elem_type = exploded.select(F.typeof(F.col("elem")).alias("elem_type")).groupBy("elem_type").count().orderBy(F.desc("count"))
    print("Observed element types (elem_type, count):")
    elem_type.show(truncate=False)

    # if elements are maps -> show keys & types
    maps = exploded.filter(F.typeof(F.col("elem")) == F.lit("map")).select(F.map_keys(F.col("elem")).alias("keys"))
    if maps.rdd.isEmpty():
        print("No map elements observed (or unable to detect).")
    else:
        print("Top map keys across elements (exploded keys):")
        (maps.select(F.explode("keys").alias("k"))
             .groupBy("k")
             .count()
             .orderBy(F.desc("count"))
             .show(top_n, truncate=False))

        # map entries types per key
        map_entries = exploded.filter(F.typeof(F.col("elem")) == F.lit("map")).select(F.explode(F.map_entries(F.col("elem"))).alias("entry"))
        map_entries_sel = map_entries.select(
            F.col("entry.key").alias("key"),
            F.col("entry.value").alias("value"),
            F.typeof(F.col("entry.value")).alias("value_type")
        ).groupBy("key", "value_type").agg(F.count("*").alias("count")).orderBy(F.desc("count"))
        print("Element map entries: key, value_type, count")
        map_entries_sel.show(top_n, truncate=False)

    # if elements are struct -> show struct schema (take first non-null element)
    structs = exploded.filter(F.typeof(F.col("elem")) == F.lit("struct"))
    if not structs.rdd.isEmpty():
        print("Sample struct element (first non-null):")
        sample_struct = structs.limit(1).collect()
        # print full row as python dict for readability
        print(sample_struct)
    else:
        print("No struct elements observed (or unable to detect).")

    # show a few exploded elems
    print("Sample exploded elements (limit 10):")
    exploded.limit(10).show(truncate=False)


# ---------------------------------------------------------------------------
# 5) Utility: safe_apply_extractor_by_schema
#    - demonstrates how to apply transform/concat_ws only after schema check
# ---------------------------------------------------------------------------
def safe_apply_array_map_extractor(df: DataFrame, col: str, elem_key: str, out_col: str = None, join_with="|"):
    """
    Safely create out_col by extracting elem_key from array<map> only when schema says column is ArrayType(MapType).
    Uses df.schema (driver-side) to decide. Returns modified DataFrame.
    """
    out_col = out_col or col
    field = next((f for f in df.schema.fields if f.name == col), None)
    if field is None:
        raise ValueError(f"Column '{col}' not in dataframe")
    t = field.dataType
    if isinstance(t, T.ArrayType) and isinstance(t.elementType, T.MapType):
        return df.withColumn(out_col, F.concat_ws(join_with, F.expr(f"transform({col}, x -> x['{elem_key}'])")))
    else:
        raise TypeError(f"Column '{col}' is not ArrayType(MapType). Detected type: {t.simpleString()}")


# ---------------------------------------------------------------------------
# 6) Convenience: explore all nested columns in the df (small prints and safe sampling)
# ---------------------------------------------------------------------------
def explore_all_nested(df: DataFrame, sample_limit: int = 5):
    """
    Runs a series of safe inspections for all columns that are Map/Array/Struct.
    Use small sample_limit to avoid huge output.
    """
    print("=== SCHEMA OVERVIEW ===")
    show_schema_overview(df)
    print("\n=== SUGGESTED EXTRACTORS ===")
    suggest_extractors(df)

    # iterate and explore deeper only for nested columns
    for f in df.schema.fields:
        t = f.dataType
        try:
            if isinstance(t, T.MapType):
                print("\n" + "-"*40)
                explore_map_column(df.select(f.name).limit(sample_limit*20), f.name, top_n=10)
            elif isinstance(t, T.ArrayType):
                print("\n" + "-"*40)
                explore_array_column(df.select(f.name).limit(sample_limit*20), f.name, top_n=10)
            elif isinstance(t, T.StructType):
                print("\n" + "-"*40)
                print(f"STRUCT column '{f.name}' fields: {[c.name for c in t.fields]}")
                print("Sample struct rows:")
                df.select(f.name).where(F.col(f.name).isNotNull()).limit(sample_limit).show(truncate=False)
        except Exception as e:
            print(f"Error exploring {f.name}: {e}")

# %%
# 1) quick overview
show_schema_overview(df)

# 2) get extractor suggestions
suggest_extractors(df)

# 3) explore a specific map col (e.g. belongs_to_collection)
explore_map_column(df, "belongs_to_collection")

# 4) explore an array of maps (e.g. genres or production_companies)
explore_array_column(df, "genres")

# 5) safely apply an extractor only when schema matches
df2 = safe_apply_array_map_extractor(df, "genres", "name", out_col="genres_names")

# 6) run a full exploration of nested columns (be careful on very large datasets)
explore_all_nested(df, sample_limit=5)
# Out:
# Column | SparkType | Nested?
# backdrop_path | string | False
# belongs_to_collection | map<string,bigint> | True
# budget | bigint | False
# credits | map<string,array<map<string,boolean>>> | True
# genres | array<map<string,bigint>> | True
# id | bigint | False
# origin_country | array<string> | True
# original_language | string | False
# overview | string | False
# popularity | double | False
# poster_path | string | False
# production_companies | array<map<string,bigint>> | True
# production_countries | array<map<string,string>> | True
# release_date | string | False
# revenue | bigint | False
# runtime | bigint | False
# spoken_languages | array<map<string,string>> | True
# status | string | False
# tagline | string | False
# title | string | False
# vote_average | double | False
# vote_count | bigint | False
# backdrop_path                  : SCALAR -> leave or cast
# belongs_to_collection          : MAP -> use col.getItem(key) or explode(map_entries(col))
# budget                         : SCALAR -> leave or cast
# credits                        : MAP -> use col.getItem(key) or explode(map_entries(col))
# genres                         : ARRAY<MAP> -> explode/transform then extract map keys (x['name'])
# id                             : SCALAR -> leave or cast
# origin_country                 : ARRAY<STRING> -> concat_ws(join_with, col)
# original_language              : SCALAR -> leave or cast
# overview                       : SCALAR -> leave or cast
# popularity                     : SCALAR -> leave or cast
# poster_path                    : SCALAR -> leave or cast
# production_companies           : ARRAY<MAP> -> explode/transform then extract map keys (x['name'])
# production_countries           : ARRAY<MAP> -> explode/transform then extract map keys (x['name'])
# release_date                   : SCALAR -> leave or cast
# revenue                        : SCALAR -> leave or cast
# runtime                        : SCALAR -> leave or cast
# spoken_languages               : ARRAY<MAP> -> explode/transform then extract map keys (x['name'])
# status                         : SCALAR -> leave or cast
# tagline                        : SCALAR -> leave or cast
# title                          : SCALAR -> leave or cast
# vote_average                   : SCALAR -> leave or cast
# vote_count                     : SCALAR -> leave or cast
# Exploring MAP column 'belongs_to_collection'
# Non-null rows: 16
# Top keys (key, count):
# +-------------+-----+
# |key          |count|
# +-------------+-----+
# |name         |16   |
# |poster_path  |16   |
# |backdrop_path|16   |
# |id           |16   |
# +-------------+-----+
#
# Key + observed value types + counts:
# +-------------+----------+-----+
# |key          |value_type|count|
# +-------------+----------+-----+
# |poster_path  |bigint    |16   |
# |id           |bigint    |16   |
# |backdrop_path|bigint    |16   |
# |name         |bigint    |16   |
# +-------------+----------+-----+
#
# Sample raw map (first 5 non-null rows):
# +-----------------------------------------------------------------------+
# |belongs_to_collection                                                  |
# +-----------------------------------------------------------------------+
# |{backdrop_path -> NULL, name -> NULL, id -> 86311, poster_path -> NULL}|
# |{backdrop_path -> NULL, name -> NULL, id -> 87096, poster_path -> NULL}|
# |{backdrop_path -> NULL, name -> NULL, id -> 10, poster_path -> NULL}   |
# |{backdrop_path -> NULL, name -> NULL, id -> 86311, poster_path -> NULL}|
# |{backdrop_path -> NULL, name -> NULL, id -> 328, poster_path -> NULL}  |
# +-----------------------------------------------------------------------+
#
# Exploring ARRAY column 'genres'
# Non-null rows: 18
# Observed element types (elem_type, count):
# +------------------+-----+
# |elem_type         |count|
# +------------------+-----+
# |map<string,bigint>|60   |
# +------------------+-----+
#
# No map elements observed (or unable to detect).
# No struct elements observed (or unable to detect).
# Sample exploded elements (limit 10):
# +-------------------------+
# |elem                     |
# +-------------------------+
# |{name -> NULL, id -> 12} |
# |{name -> NULL, id -> 878}|
# |{name -> NULL, id -> 28} |
# |{name -> NULL, id -> 28} |
# |{name -> NULL, id -> 12} |
# |{name -> NULL, id -> 14} |
# |{name -> NULL, id -> 878}|
# |{name -> NULL, id -> 12} |
# |{name -> NULL, id -> 28} |
# |{name -> NULL, id -> 878}|
# +-------------------------+
#
# === SCHEMA OVERVIEW ===
# Column | SparkType | Nested?
# backdrop_path | string | False
# belongs_to_collection | map<string,bigint> | True
# budget | bigint | False
# credits | map<string,array<map<string,boolean>>> | True
# genres | array<map<string,bigint>> | True
# id | bigint | False
# origin_country | array<string> | True
# original_language | string | False
# overview | string | False
# popularity | double | False
# poster_path | string | False
# production_companies | array<map<string,bigint>> | True
# production_countries | array<map<string,string>> | True
# release_date | string | False
# revenue | bigint | False
# runtime | bigint | False
# spoken_languages | array<map<string,string>> | True
# status | string | False
# tagline | string | False
# title | string | False
# vote_average | double | False
# vote_count | bigint | False
#
# === SUGGESTED EXTRACTORS ===
# backdrop_path                  : SCALAR -> leave or cast
# belongs_to_collection          : MAP -> use col.getItem(key) or explode(map_entries(col))
# budget                         : SCALAR -> leave or cast
# credits                        : MAP -> use col.getItem(key) or explode(map_entries(col))
# genres                         : ARRAY<MAP> -> explode/transform then extract map keys (x['name'])
# id                             : SCALAR -> leave or cast
# origin_country                 : ARRAY<STRING> -> concat_ws(join_with, col)
# original_language              : SCALAR -> leave or cast
# overview                       : SCALAR -> leave or cast
# popularity                     : SCALAR -> leave or cast
# poster_path                    : SCALAR -> leave or cast
# production_companies           : ARRAY<MAP> -> explode/transform then extract map keys (x['name'])
# production_countries           : ARRAY<MAP> -> explode/transform then extract map keys (x['name'])
# release_date                   : SCALAR -> leave or cast
# revenue                        : SCALAR -> leave or cast
# runtime                        : SCALAR -> leave or cast
# spoken_languages               : ARRAY<MAP> -> explode/transform then extract map keys (x['name'])
# status                         : SCALAR -> leave or cast
# tagline                        : SCALAR -> leave or cast
# title                          : SCALAR -> leave or cast
# vote_average                   : SCALAR -> leave or cast
# vote_count                     : SCALAR -> leave or cast
#
# ----------------------------------------
# Exploring MAP column 'belongs_to_collection'
# Non-null rows: 16
# Top keys (key, count):
# +-------------+-----+
# |key          |count|
# +-------------+-----+
# |backdrop_path|16   |
# |name         |16   |
# |id           |16   |
# |poster_path  |16   |
# +-------------+-----+
#
# Key + observed value types + counts:
# +-------------+----------+-----+
# |key          |value_type|count|
# +-------------+----------+-----+
# |backdrop_path|bigint    |16   |
# |name         |bigint    |16   |
# |id           |bigint    |16   |
# |poster_path  |bigint    |16   |
# +-------------+----------+-----+
#
# Sample raw map (first 5 non-null rows):
# +-----------------------------------------------------------------------+
# |belongs_to_collection                                                  |
# +-----------------------------------------------------------------------+
# |{backdrop_path -> NULL, name -> NULL, id -> 86311, poster_path -> NULL}|
# |{backdrop_path -> NULL, name -> NULL, id -> 87096, poster_path -> NULL}|
# |{backdrop_path -> NULL, name -> NULL, id -> 10, poster_path -> NULL}   |
# |{backdrop_path -> NULL, name -> NULL, id -> 86311, poster_path -> NULL}|
# |{backdrop_path -> NULL, name -> NULL, id -> 328, poster_path -> NULL}  |
# +-----------------------------------------------------------------------+
#
#
# ----------------------------------------
# Exploring MAP column 'credits'
# Non-null rows: 18
# Top keys (key, count):
# +----+-----+
# |key |count|
# +----+-----+
# |cast|18   |
# |crew|18   |
# +----+-----+
#
# Key + observed value types + counts:
# +----+--------------------------+-----+
# |key |value_type                |count|
# +----+--------------------------+-----+
# |cast|array<map<string,boolean>>|18   |
# |crew|array<map<string,boolean>>|18   |
# +----+--------------------------+-----+
#
# Sample raw map (first 5 non-null rows):
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |credits                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |{cast -> [{cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NUL ...
# |{cast -> [{cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NUL ...
# |{cast -> [{cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NUL ...
# |{cast -> [{cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NUL ...
# |{cast -> [{cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NUL ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
#
#
# ----------------------------------------
# Exploring ARRAY column 'genres'
# Non-null rows: 18
# Observed element types (elem_type, count):
# +------------------+-----+
# |elem_type         |count|
# +------------------+-----+
# |map<string,bigint>|60   |
# +------------------+-----+
#
# No map elements observed (or unable to detect).
# No struct elements observed (or unable to detect).
# Sample exploded elements (limit 10):
# +-------------------------+
# |elem                     |
# +-------------------------+
# |{name -> NULL, id -> 12} |
# |{name -> NULL, id -> 878}|
# |{name -> NULL, id -> 28} |
# |{name -> NULL, id -> 28} |
# |{name -> NULL, id -> 12} |
# |{name -> NULL, id -> 14} |
# |{name -> NULL, id -> 878}|
# |{name -> NULL, id -> 12} |
# |{name -> NULL, id -> 28} |
# |{name -> NULL, id -> 878}|
# +-------------------------+
#
#
# ----------------------------------------
# Exploring ARRAY column 'origin_country'
# Non-null rows: 18
# Observed element types (elem_type, count):
# +---------+-----+
# |elem_type|count|
# +---------+-----+
# |string   |18   |
# +---------+-----+
#
# Error exploring origin_country: [DATATYPE_MISMATCH.UNEXPECTED_INPUT_TYPE] Cannot resolve "map_keys(elem)" due to data type mismatch: Parameter 1 requires the "MAP" type, however "elem" has the type "STRING".;
# 'Project [map_keys(elem#594) AS keys#616]
# +- Filter (typeof(elem#594) = map)
#    +- Project [elem#594]
#       +- Generate explode(origin_country#9), false, [elem#594]
#          +- GlobalLimit 100
#             +- LocalLimit 100
#                +- Project [origin_country#9]
#                   +- Project [backdrop_path#1, belongs_to_collection#2, budget#3L, credits#4, genres#5, id#7L, origin_country#9, original_language#10, overview#12, popularity#13, poster_path#14, production_companies#15, production_countries#16, release_date#17, revenue#18L, runtime#19L, spoken_languages#20, status#21, tagline#22, title#23, vote_average#25, vote_count#26L]
#                      +- LogicalRDD [adult#0, backdrop_path#1, belongs_to_collection#2, budget#3L, credits#4, genres#5, homepage#6, id#7L, imdb_id#8, origin_country#9, original_language#10, original_title#11, overview#12, popularity#13, poster_path#14, production_companies#15, production_countries#16, release_date#17, revenue#18L, runtime#19L, spoken_languages#20, status#21, tagline#22, title#23, ... 3 more fields], false
#
#
# ----------------------------------------
# Exploring ARRAY column 'production_companies'
# Non-null rows: 18
# Observed element types (elem_type, count):
# +------------------+-----+
# |elem_type         |count|
# +------------------+-----+
# |map<string,bigint>|32   |
# +------------------+-----+
#
# No map elements observed (or unable to detect).
# No struct elements observed (or unable to detect).
# Sample exploded elements (limit 10):
# +-----------------------------------------------------------------------+
# |elem                                                                   |
# +-----------------------------------------------------------------------+
# |{name -> NULL, id -> 420, logo_path -> NULL, origin_country -> NULL}   |
# |{name -> NULL, id -> 444, logo_path -> NULL, origin_country -> NULL}   |
# |{name -> NULL, id -> 574, logo_path -> NULL, origin_country -> NULL}   |
# |{name -> NULL, id -> 25, logo_path -> NULL, origin_country -> NULL}    |
# |{name -> NULL, id -> 133789, logo_path -> NULL, origin_country -> NULL}|
# |{name -> NULL, id -> 1, logo_path -> NULL, origin_country -> NULL}     |
# |{name -> NULL, id -> 11461, logo_path -> NULL, origin_country -> NULL} |
# |{name -> NULL, id -> 420, logo_path -> NULL, origin_country -> NULL}   |
# |{name -> NULL, id -> 4, logo_path -> NULL, origin_country -> NULL}     |
# |{name -> NULL, id -> 25, logo_path -> NULL, origin_country -> NULL}    |
# +-----------------------------------------------------------------------+
#
#
# ----------------------------------------
# Exploring ARRAY column 'production_countries'
# Non-null rows: 18
# Observed element types (elem_type, count):
# +------------------+-----+
# |elem_type         |count|
# +------------------+-----+
# |map<string,string>|20   |
# +------------------+-----+
#
# No map elements observed (or unable to detect).
# No struct elements observed (or unable to detect).
# Sample exploded elements (limit 10):
# +----------------------------------------------------+
# |elem                                                |
# +----------------------------------------------------+
# |{name -> United States of America, iso_3166_1 -> US}|
# |{name -> United States of America, iso_3166_1 -> US}|
# |{name -> United Kingdom, iso_3166_1 -> GB}          |
# |{name -> United States of America, iso_3166_1 -> US}|
# |{name -> United States of America, iso_3166_1 -> US}|
# |{name -> United States of America, iso_3166_1 -> US}|
# |{name -> United States of America, iso_3166_1 -> US}|
# |{name -> United States of America, iso_3166_1 -> US}|
# |{name -> United States of America, iso_3166_1 -> US}|
# |{name -> United States of America, iso_3166_1 -> US}|
# +----------------------------------------------------+
#
#
# ----------------------------------------
# Exploring ARRAY column 'spoken_languages'
# Non-null rows: 18
# Observed element types (elem_type, count):
# +------------------+-----+
# |elem_type         |count|
# +------------------+-----+
# |map<string,string>|37   |
# +------------------+-----+
#
# No map elements observed (or unable to detect).
# No struct elements observed (or unable to detect).
# Sample exploded elements (limit 10):
# +-----------------------------------------------------------+
# |elem                                                       |
# +-----------------------------------------------------------+
# |{name -> English, iso_639_1 -> en, english_name -> English}|
# |{name -> 日本語, iso_639_1 -> ja, english_name -> Japanese}|
# |{name -> , iso_639_1 -> xh, english_name -> Xhosa}         |
# |{name -> English, iso_639_1 -> en, english_name -> English}|
# |{name -> Español, iso_639_1 -> es, english_name -> Spanish}|
# |{name -> English, iso_639_1 -> en, english_name -> English}|
# |{name -> English, iso_639_1 -> en, english_name -> English}|
# |{name -> , iso_639_1 -> xh, english_name -> Xhosa}         |
# |{name -> English, iso_639_1 -> en, english_name -> English}|
# |{name -> Français, iso_639_1 -> fr, english_name -> French}|
# +-----------------------------------------------------------+

# %%
from pyspark.sql import SparkSession, DataFrame, functions as F
from pyspark.sql.types import *

# -------------------------
# 1️⃣ Create Spark session
# -------------------------
spark = SparkSession.builder \
    .appName("TMDB Movie Cleaner") \
    .getOrCreate()

# -------------------------
# 2️⃣ Define explicit schemas
# -------------------------

# id + name struct (for genres, companies, languages)
id_name_schema = StructType([
    StructField("id", LongType(), True),
    StructField("name", StringType(), True)
])

# Collection schema
collection_schema = StructType([
    StructField("id", LongType(), True),
    StructField("name", StringType(), True),
    StructField("poster_path", StringType(), True),
    StructField("backdrop_path", StringType(), True)
])

# Cast / Crew person schema
credit_person_schema = StructType([
    StructField("id", LongType(), True),
    StructField("name", StringType(), True),
    StructField("job", StringType(), True),
    StructField("character", StringType(), True),
    StructField("adult", BooleanType(), True)
])

# Credits schema
credits_schema = StructType([
    StructField("cast", ArrayType(credit_person_schema), True),
    StructField("crew", ArrayType(credit_person_schema), True)
])

# -------------------------
# 3️⃣ Helper extraction functions
# -------------------------

def extract_array_map_field(df: DataFrame, col: str, key: str, join_with: str = "|") -> DataFrame:
    """Extract key from array<map> and join as string"""
    return df.withColumn(col, F.concat_ws(join_with, F.expr(f"transform({col}, x -> x.{key})")))

def extract_collection_field(df: DataFrame, col: str = "belongs_to_collection", key: str = "name") -> DataFrame:
    """Extract a field from belongs_to_collection"""
    return df.withColumn(col + "_" + key, F.col(col + "." + key))

def extract_credits(df: DataFrame) -> DataFrame:
    """Extract cast, cast_size, director, crew_size"""
    df = df.withColumn(
        "cast",
        F.concat_ws("|", F.expr("transform(credits.cast, x -> x.name)"))
    ).withColumn(
        "cast_size",
        F.size(F.col("credits.cast"))
    ).withColumn(
        "director",
        F.concat_ws(
            "|",
            F.expr("transform(filter(credits.crew, x -> x.job = 'Director'), x -> x.name)")
        )
    ).withColumn(
        "crew_size",
        F.size(F.col("credits.crew"))
    ).drop("credits")
    return df

def extract_origin_country(df: DataFrame, col: str = "origin_country", join_with: str = "|") -> DataFrame:
    """Join array<string> into single string"""
    return df.withColumn(col, F.concat_ws(join_with, F.col(col)))

# -------------------------
# 4️⃣ Main cleaning function
# -------------------------

def clean_movie_data(df: DataFrame) -> DataFrame:

    # --- Re-parse nested JSONs with explicit schemas ---
    df = df.withColumn("genres", F.from_json(F.to_json("genres"), ArrayType(id_name_schema)))
    df = df.withColumn("production_companies", F.from_json(F.to_json("production_companies"), ArrayType(id_name_schema)))
    df = df.withColumn("production_countries", F.from_json(F.to_json("production_countries"),
                                                           ArrayType(StructType([
                                                               StructField("iso_3166_1", StringType(), True),
                                                               StructField("name", StringType(), True)
                                                           ]))))
    df = df.withColumn("spoken_languages", F.from_json(F.to_json("spoken_languages"), ArrayType(id_name_schema)))
    df = df.withColumn("belongs_to_collection", F.from_json(F.to_json("belongs_to_collection"), collection_schema))
    df = df.withColumn("credits", F.from_json(F.to_json("credits"), credits_schema))

    # --- Extract collection name ---
    df = extract_collection_field(df, "belongs_to_collection", "name")

    # --- Extract genres, companies, countries, languages ---
    df = extract_array_map_field(df, "genres", "name")
    df = extract_array_map_field(df, "production_companies", "name")
    df = extract_array_map_field(df, "production_countries", "name")
    df = extract_array_map_field(df, "spoken_languages", "name")

    # --- Extract origin_country (array<string>) ---
    df = extract_origin_country(df, "origin_country")

    # --- Extract cast & crew ---
    df = extract_credits(df)

    # --- Convert numeric columns ---
    numeric_columns = ["budget", "popularity", "id", "revenue", "runtime", "vote_average", "vote_count"]
    for c in numeric_columns:
        df = df.withColumn(c, F.col(c).cast("double"))

    # --- Convert release_date to date ---
    df = df.withColumn("release_date", F.to_date("release_date", "yyyy-MM-dd"))

    return df

# -------------------------
# 5️⃣ Example usage
# -------------------------

# Suppose `movies` is a Python list of dicts from the API
df = spark.createDataFrame(movies)

# Cleaned DF
df_clean = clean_movie_data(df)

# Optional: show cleaned data
df_clean.toPandas()
# Out:
#     adult                     backdrop_path       belongs_to_collection  \
# 0   False  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg   (86311, None, None, None)
# 1   False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg   (87096, None, None, None)
# 2   False  /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg      (10, None, None, None)
# 3   False  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg   (86311, None, None, None)
# 4   False  /xnHVX37XZEp33hhCbYlQFq7ux1J.jpg                        None
# 5   False  /s5QfDFqRO6sjgPtKkjxD0WqXQef.jpg     (328, None, None, None)
# 6   False  /1TUg5pO1VZ4B0Q1amk3OlXvlpXV.jpg  (762512, None, None, None)
# 7   False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg   (86311, None, None, None)
# 8   False  /ehzI1mVcnHqB58NqPyQwpMqcVoz.jpg    (9485, None, None, None)
# 9   False  /kIBK5SKwgqIIuRKhhWrJn3XkbPq.jpg   (86311, None, None, None)
# 10  False  /19Ed4XgjahPm4U8JT7SnntERIlt.jpg  (529892, None, None, None)
# 11  False  /cbcpDn6XJaIGoOil1bKuskU8ds4.jpg    (1241, None, None, None)
# 12  False  /5Iw7zQTHVRBOYpA0V6z0yypOPZh.jpg      (10, None, None, None)
# 13  False  /AoSZyb37ljMAxw0RdeQEBHKtgcc.jpg  (386382, None, None, None)
# 14  False  /6WA9stUMbIkEPxn3D5SWlA8FIi7.jpg     (328, None, None, None)
# 15  False  /9WHM084AoskcHCObAy4QnJg01eM.jpg  (386382, None, None, None)
# 16  False  /uU1Mt4JWhDvl4vKb3AfxNsorkoM.jpg                        None
# 17  False  /mabuNsGJgRuCTuGqjFkWe1xdu19.jpg  (468222, None, None, None)
#
#          budget genres                                           homepage  \
# 0   356000000.0            https://www.marvel.com/movies/avengers-endgame
# 1   237000000.0                      https://www.avatar.com/movies/avatar
# 2   245000000.0         http://www.starwars.com/films/star-wars-episod...
# 3   300000000.0         https://www.marvel.com/movies/avengers-infinit...
# 4   200000000.0            https://www.paramountmovies.com/movies/titanic
# 5   150000000.0                            https://www.jurassicworld.com/
# 6   260000000.0              https://movies.disney.com/the-lion-king-2019
# 7   220000000.0                https://www.marvel.com/movies/the-avengers
# 8   190000000.0                     https://www.uphe.com/movies/furious-7
# 9   235000000.0         https://www.marvel.com/movies/avengers-age-of-...
# 10  200000000.0               https://www.marvel.com/movies/black-panther
# 11  125000000.0         https://www.warnerbros.com/movies/harry-potter...
# 12  300000000.0         https://www.starwars.com/films/star-wars-episo...
# 13  150000000.0                        https://movies.disney.com/frozen-2
# 14  170000000.0         https://www.uphe.com/movies/jurassic-world-fal...
# 15  150000000.0                           http://movies.disney.com/frozen
# 16  160000000.0         http://movies.disney.com/beauty-and-the-beast-...
# 17  200000000.0                   https://movies.disney.com/incredibles-2
#
#           id    imdb_id origin_country original_language  ...  \
# 0   299534.0  tt4154796             US                en  ...
# 1    19995.0  tt0499549             US                en  ...
# 2   140607.0  tt2488496             US                en  ...
# 3   299536.0  tt4154756             US                en  ...
# 4      597.0  tt0120338             US                en  ...
# 5   135397.0  tt0369610             US                en  ...
# 6   420818.0  tt6105098             US                en  ...
# 7    24428.0  tt0848228             US                en  ...
# 8   168259.0  tt2820852             US                en  ...
# 9    99861.0  tt2395427             US                en  ...
# 10  284054.0  tt1825683             US                en  ...
# 11   12445.0  tt1201607             GB                en  ...
# 12  181808.0  tt2527336             US                en  ...
# 13  330457.0  tt4520988             US                en  ...
# 14  351286.0  tt4881806             US                en  ...
# 15  109445.0  tt2294629             US                en  ...
# 16  321612.0  tt2771200             US                en  ...
# 17  260513.0  tt3606756             US                en  ...
#
#                                               tagline  \
# 0                                  Avenge the fallen.
# 1                         Enter the world of Pandora.
# 2                       Every generation has a story.
# 3                       Destiny arrives all the same.
# 4           Nothing on earth could come between them.
# 5                                   The park is open.
# 6                              The king has returned.
# 7                             Some assembly required.
# 8                                Vengeance hits home.
# 9                                 A new age has come.
# 10                                Long live the king.
# 11                                       It all ends.
# 12                                  Let the past die.
# 13                     The past is not what it seems.
# 14                                  The park is gone.
# 15  Who will save the day? The ice guy? The nice g...
# 16                                      Be our guest.
# 17                      It's been too long, dahlings.
#
#                                            title  video vote_average  \
# 0                              Avengers: Endgame  False        8.238
# 1                                         Avatar  False        7.600
# 2                   Star Wars: The Force Awakens  False        7.254
# 3                         Avengers: Infinity War  False        8.235
# 4                                        Titanic  False        7.903
# 5                                 Jurassic World  False        6.700
# 6                                  The Lion King  False        7.099
# 7                                   The Avengers  False        7.904
# 8                                      Furious 7  False        7.219
# 9                        Avengers: Age of Ultron  False        7.271
# 10                                 Black Panther  False        7.365
# 11  Harry Potter and the Deathly Hallows: Part 2  False        8.083
# 12                      Star Wars: The Last Jedi  False        6.762
# 13                                     Frozen II  False        7.238
# 14                Jurassic World: Fallen Kingdom  False        6.500
# 15                                        Frozen  False        7.248
# 16                          Beauty and the Beast  False        7.000
# 17                                 Incredibles 2  False        7.454
#
#    vote_count belongs_to_collection_name cast  cast_size  director crew_size
# 0     27125.0                       None             107                 608
# 1     33240.0                       None              67                 991
# 2     20198.0                       None             183                 264
# 3     31335.0                       None              69                 734
# 4     26659.0                       None             116                 262
# 5     21216.0                       None              53                 428
# 6     10602.0                       None              20                  50
# 7     35071.0                       None             113                 642
# 8     11089.0                       None              49                 228
# 9     24002.0                       None              74                 653
# 10    23075.0                       None              66                 567
# 11    21570.0                       None             105                 159
# 12    16017.0                       None             111                 221
# 13    10119.0                       None              64                  41
# 14    12481.0                       None              41                 384
# 15    17273.0                       None              60                 285
# 16    15875.0                       None             139                 158
# 17    13442.0                       None              84                 260
#
# [18 rows x 31 columns]
