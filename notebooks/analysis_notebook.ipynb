# %%
from pathlib import Path
import sys 

sys.path.append(str(Path.cwd().parent))

from pyspark.sql import SparkSession
import os

# Path to log4j.properties
notebook_dir = Path().resolve()
log4j_path = log4j_path = notebook_dir.parent / "conf" / "log4j.properties"

spark = (
    SparkSession.builder
    .appName("MovieProject")
    .config("spark.driver.extraJavaOptions", f"-Dlog4j.configuration=file:{log4j_path}")
    .config("spark.executor.extraJavaOptions", f"-Dlog4j.configuration=file:{log4j_path}")
    .getOrCreate()
)

spark.sparkContext.setLogLevel("WARN") 

# %reload_ext autoreload
# %autoreload 2

import scripts.extraction.extractor_tmdb as tmdb
# import transform.clean_data as cln
# import analysis.kpi_analysis as kpi 
# import visualize.visualizations as viz
# Out:
# Setting default log level to "INFO".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
zootopia_details = tmdb.get_movie_details(1084242)
zootopia_details = spark.createDataFrame([zootopia_details])

# %%
movie_ids = [0, 299534, 19995, 140607, 299536, 597, 135397, 420818, 24428, 168259, 99861, 284054, 12445, 181808, 330457, 351286, 109445, 321612, 260513]

# %%
movies = tmdb.get_all_movies_by_ids(movie_ids)
# Out:
# 2026-01-14 15:22:56,463 - INFO - extractor_tmdb - Fetching movie ID: 0
# 2026-01-14 15:22:56,940 - ERROR - extractor_tmdb - HTTP error on attempt 0: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?append_to_response=credits&api_key=d855a01d02babf081991d455eff39348&language=en-US&movie_id=0
# 2026-01-14 15:22:59,339 - ERROR - extractor_tmdb - HTTP error on attempt 1: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?append_to_response=credits&api_key=d855a01d02babf081991d455eff39348&language=en-US&movie_id=0
# 2026-01-14 15:23:01,702 - ERROR - extractor_tmdb - HTTP error on attempt 2: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?append_to_response=credits&api_key=d855a01d02babf081991d455eff39348&language=en-US&movie_id=0
# 2026-01-14 15:23:04,079 - ERROR - extractor_tmdb - HTTP error on attempt 3: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?append_to_response=credits&api_key=d855a01d02babf081991d455eff39348&language=en-US&movie_id=0
# 2026-01-14 15:23:06,624 - ERROR - extractor_tmdb - HTTP error on attempt 4: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?append_to_response=credits&api_key=d855a01d02babf081991d455eff39348&language=en-US&movie_id=0
# 2026-01-14 15:23:08,948 - ERROR - extractor_tmdb - HTTP error on attempt 5: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?append_to_response=credits&api_key=d855a01d02babf081991d455eff39348&language=en-US&movie_id=0
# 2026-01-14 15:23:08,950 - ERROR - extractor_tmdb - Failed after 5 attempts: https://api.themoviedb.org/3/movie/0?append_to_response=credits
# 2026-01-14 15:23:08,952 - ERROR - extractor_tmdb - Failed to fetch movies 0: Max retries reached.
# 2026-01-14 15:23:08,955 - WARNING - extractor_tmdb - Skipping movie ID 0 due to fetch error: Max retries reached.
# 2026-01-14 15:23:08,957 - INFO - extractor_tmdb - Fetching movie ID: 299534
# 2026-01-14 15:23:09,569 - INFO - extractor_tmdb - Fetching movie ID: 19995
# 2026-01-14 15:23:10,145 - INFO - extractor_tmdb - Fetching movie ID: 140607
# 2026-01-14 15:23:10,665 - INFO - extractor_tmdb - Fetching movie ID: 299536
# 2026-01-14 15:23:11,292 - INFO - extractor_tmdb - Fetching movie ID: 597
# 2026-01-14 15:23:11,818 - INFO - extractor_tmdb - Fetching movie ID: 135397
# 2026-01-14 15:23:12,361 - INFO - extractor_tmdb - Fetching movie ID: 420818
# 2026-01-14 15:23:12,832 - INFO - extractor_tmdb - Fetching movie ID: 24428
# 2026-01-14 15:23:13,402 - INFO - extractor_tmdb - Fetching movie ID: 168259
# 2026-01-14 15:23:13,854 - INFO - extractor_tmdb - Fetching movie ID: 99861
# 2026-01-14 15:23:14,363 - INFO - extractor_tmdb - Fetching movie ID: 284054
# 2026-01-14 15:23:14,824 - INFO - extractor_tmdb - Fetching movie ID: 12445
# 2026-01-14 15:23:15,327 - INFO - extractor_tmdb - Fetching movie ID: 181808
# 2026-01-14 15:23:15,824 - INFO - extractor_tmdb - Fetching movie ID: 330457
# 2026-01-14 15:23:16,505 - INFO - extractor_tmdb - Fetching movie ID: 351286
# 2026-01-14 15:23:16,978 - INFO - extractor_tmdb - Fetching movie ID: 109445
# 2026-01-14 15:23:17,485 - INFO - extractor_tmdb - Fetching movie ID: 321612
# 2026-01-14 15:23:17,968 - INFO - extractor_tmdb - Fetching movie ID: 260513

# %%
df = spark.createDataFrame(movies)

# %%
df.printSchema()
# Out:
# root
#  |-- adult: boolean (nullable = true)
#  |-- backdrop_path: string (nullable = true)
#  |-- belongs_to_collection: map (nullable = true)
#  |    |-- key: string
#  |    |-- value: long (valueContainsNull = true)
#  |-- budget: long (nullable = true)
#  |-- credits: map (nullable = true)
#  |    |-- key: string
#  |    |-- value: array (valueContainsNull = true)
#  |    |    |-- element: map (containsNull = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: boolean (valueContainsNull = true)
#  |-- genres: array (nullable = true)
#  |    |-- element: map (containsNull = true)
#  |    |    |-- key: string
#  |    |    |-- value: long (valueContainsNull = true)
#  |-- homepage: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- imdb_id: string (nullable = true)
#  |-- origin_country: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- original_language: string (nullable = true)
#  |-- original_title: string (nullable = true)
#  |-- overview: string (nullable = true)
#  |-- popularity: double (nullable = true)
#  |-- poster_path: string (nullable = true)
#  |-- production_companies: array (nullable = true)
#  |    |-- element: map (containsNull = true)
#  |    |    |-- key: string
#  |    |    |-- value: long (valueContainsNull = true)
#  |-- production_countries: array (nullable = true)
#  |    |-- element: map (containsNull = true)
#  |    |    |-- key: string
#  |    |    |-- value: string (valueContainsNull = true)
#  |-- release_date: string (nullable = true)
#  |-- revenue: long (nullable = true)
#  |-- runtime: long (nullable = true)
#  |-- spoken_languages: array (nullable = true)
#  |    |-- element: map (containsNull = true)
#  |    |    |-- key: string
#  |    |    |-- value: string (valueContainsNull = true)
#  |-- status: string (nullable = true)
#  |-- tagline: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- video: boolean (nullable = true)
#  |-- vote_average: double (nullable = true)
#  |-- vote_count: long (nullable = true)

# %%
df.limit(10).show(truncate=False)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
df.columns
