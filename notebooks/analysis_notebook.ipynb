# %%
from pathlib import Path
import sys 
import pandas as pd
import json

sys.path.append(str(Path.cwd().parent))

from pyspark.sql import SparkSession
import os

# Path to log4j.properties
notebook_dir = Path().resolve()
log4j_path = log4j_path = notebook_dir.parent / "conf" / "log4j.properties"

spark = (
    SparkSession.builder
    .appName("MovieProject")
    .config("spark.driver.extraJavaOptions", f"-Dlog4j.configuration=file:{log4j_path}")
    .config("spark.executor.extraJavaOptions", f"-Dlog4j.configuration=file:{log4j_path}")
    .getOrCreate()
)

spark.sparkContext.setLogLevel("WARN") 

# %reload_ext autoreload
# %autoreload 2

import scripts.extraction.extractor_tmdb as tmdb
import scripts.transform.clean_data as cln
import scripts.transform.tmdb_data_preprocessor as dp
import scripts.transform.tmdb_schema as ts
# import analysis.kpi_analysis as kpi 
# import visualize.visualizations as viz
# Out:
# Setting default log level to "INFO".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %% [markdown]
# ## Fetch all movies and store in a Database

# %%
movie_ids = [0, 299534, 19995, 140607, 299536, 597, 135397, 420818, 24428, 168259, 99861, 284054, 12445, 181808, 330457, 351286, 109445, 321612, 260513]

# %%
movies = tmdb.get_all_movies_by_ids(movie_ids)
# Out:
# 2026-01-16 12:02:25,866 - INFO - extractor_tmdb - Fetching movie ID: 0
# 2026-01-16 12:02:26,547 - ERROR - extractor_tmdb - HTTP error on attempt 0: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?append_to_response=credits&api_key=d855a01d02babf081991d455eff39348&language=en-US&movie_id=0
# 2026-01-16 12:02:28,977 - ERROR - extractor_tmdb - HTTP error on attempt 1: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?append_to_response=credits&api_key=d855a01d02babf081991d455eff39348&language=en-US&movie_id=0
# 2026-01-16 12:02:31,374 - ERROR - extractor_tmdb - HTTP error on attempt 2: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?append_to_response=credits&api_key=d855a01d02babf081991d455eff39348&language=en-US&movie_id=0
# 2026-01-16 12:02:33,790 - ERROR - extractor_tmdb - HTTP error on attempt 3: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?append_to_response=credits&api_key=d855a01d02babf081991d455eff39348&language=en-US&movie_id=0
# 2026-01-16 12:02:36,207 - ERROR - extractor_tmdb - HTTP error on attempt 4: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?append_to_response=credits&api_key=d855a01d02babf081991d455eff39348&language=en-US&movie_id=0
# 2026-01-16 12:02:38,706 - ERROR - extractor_tmdb - HTTP error on attempt 5: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/0?append_to_response=credits&api_key=d855a01d02babf081991d455eff39348&language=en-US&movie_id=0
# 2026-01-16 12:02:38,709 - ERROR - extractor_tmdb - Failed after 5 attempts: https://api.themoviedb.org/3/movie/0?append_to_response=credits
# 2026-01-16 12:02:38,711 - ERROR - extractor_tmdb - Failed to fetch movies 0: Max retries reached.
# 2026-01-16 12:02:38,712 - WARNING - extractor_tmdb - Skipping movie ID 0 due to fetch error: Max retries reached.
# 2026-01-16 12:02:38,713 - INFO - extractor_tmdb - Fetching movie ID: 299534
# 2026-01-16 12:02:39,409 - INFO - extractor_tmdb - Fetching movie ID: 19995
# 2026-01-16 12:02:40,058 - INFO - extractor_tmdb - Fetching movie ID: 140607
# 2026-01-16 12:02:40,627 - INFO - extractor_tmdb - Fetching movie ID: 299536
# 2026-01-16 12:02:41,305 - INFO - extractor_tmdb - Fetching movie ID: 597
# 2026-01-16 12:02:41,845 - INFO - extractor_tmdb - Fetching movie ID: 135397
# 2026-01-16 12:02:42,386 - INFO - extractor_tmdb - Fetching movie ID: 420818
# 2026-01-16 12:02:42,998 - INFO - extractor_tmdb - Fetching movie ID: 24428
# 2026-01-16 12:02:43,636 - INFO - extractor_tmdb - Fetching movie ID: 168259
# 2026-01-16 12:02:44,200 - INFO - extractor_tmdb - Fetching movie ID: 99861
# 2026-01-16 12:02:44,848 - INFO - extractor_tmdb - Fetching movie ID: 284054
# 2026-01-16 12:02:45,366 - INFO - extractor_tmdb - Fetching movie ID: 12445
# 2026-01-16 12:02:45,906 - INFO - extractor_tmdb - Fetching movie ID: 181808
# 2026-01-16 12:02:46,446 - INFO - extractor_tmdb - Fetching movie ID: 330457
# 2026-01-16 12:02:46,960 - INFO - extractor_tmdb - Fetching movie ID: 351286
# 2026-01-16 12:02:47,519 - INFO - extractor_tmdb - Fetching movie ID: 109445
# 2026-01-16 12:02:48,027 - INFO - extractor_tmdb - Fetching movie ID: 321612
# 2026-01-16 12:02:48,555 - INFO - extractor_tmdb - Fetching movie ID: 260513

# %%
output_path = Path("tmdb_raw_movies.jsonl")

with output_path.open("w", encoding="utf-8") as f:
    for movie in movies:
        if movie:
            json.dump(movie, f, ensure_ascii=False)
            f.write("\n")

print(f"Saved {len(movies)} movies to {output_path}")
# Out:
# Saved 18 movies to tmdb_raw_movies.jsonl

# %%
df = spark.read \
    .option("multiLine", "False") \
    .schema(ts.data_schema) \
    .json(str(output_path))

# %%
df.printSchema()
# Out:
# root
#  |-- adult: boolean (nullable = true)
#  |-- backdrop_path: string (nullable = true)
#  |-- belongs_to_collection: struct (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- poster_path: string (nullable = true)
#  |    |-- backdrop_path: string (nullable = true)
#  |-- budget: long (nullable = true)
#  |-- genres: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: integer (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |-- homepage: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- imdb_id: string (nullable = true)
#  |-- origin_country: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- original_language: string (nullable = true)
#  |-- original_title: string (nullable = true)
#  |-- overview: string (nullable = true)
#  |-- popularity: double (nullable = true)
#  |-- poster_path: string (nullable = true)
#  |-- production_companies: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: integer (nullable = true)
#  |    |    |-- logo_path: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- origin_country: string (nullable = true)
#  |-- production_countries: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- iso_3166_1: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |-- release_date: string (nullable = true)
#  |-- revenue: long (nullable = true)
#  |-- runtime: integer (nullable = true)
#  |-- spoken_languages: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- english_name: string (nullable = true)
#  |    |    |-- iso_639_1: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- tagline: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- video: boolean (nullable = true)
#  |-- vote_average: double (nullable = true)
#  |-- vote_count: long (nullable = true)
#  |-- credits: struct (nullable = true)
#  |    |-- cast: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- adult: boolean (nullable = true)
#  |    |    |    |-- gender: integer (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- known_for_department: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- original_name: string (nullable = true)
#  |    |    |    |-- popularity: double (nullable = true)
#  |    |    |    |-- profile_path: string (nullable = true)
#  |    |    |    |-- cast_id: integer (nullable = true)
#  |    |    |    |-- character: string (nullable = true)
#  |    |    |    |-- credit_id: string (nullable = true)
#  |    |    |    |-- order: integer (nullable = true)
#  |    |-- crew: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- adult: boolean (nullable = true)
#  |    |    |    |-- gender: integer (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- known_for_department: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- original_name: string (nullable = true)
#  |    |    |    |-- popularity: double (nullable = true)
#  |    |    |    |-- profile_path: string (nullable = true)
#  |    |    |    |-- credit_id: string (nullable = true)
#  |    |    |    |-- department: string (nullable = true)
#  |    |    |    |-- job: string (nullable = true)

# %%
categorical_columns = ['belongs_to_collection', 'genres', 'production_countries', 'production_companies', 'spoken_languages', 'origin_country',"credits.cast", "credits.crew"]

# %%
df.select(*categorical_columns).show(3, truncate=100, vertical=True)
# Out:
# -RECORD 0---------------------------------------------------------------------------------------------------------------------
#  belongs_to_collection | {86311, The Avengers Collection, /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg, /zuW6fOiusv4X9nnW3paHGfXcSll.jpg}
#  genres                | [{12, Adventure}, {878, Science Fiction}, {28, Action}]
#  production_countries  | [{US, United States of America}]
#  production_companies  | [{420, /hUzeosd33nzE5MCNsZxCGEKTXaQ.png, Marvel Studios, US}]
#  spoken_languages      | [{English, en, English}, {Japanese, ja, 日本語}, {Xhosa, xh, }]
#  origin_country        | [US]
#  cast                  | [{false, 2, 3223, Acting, Robert Downey Jr., Robert Downey Jr., 9.9269, /5qHNjhtjMD4YWH3UP0rm4tKw...
#  crew                  | [{false, 0, 3019687, Directing, Paul Schneider, Paul Schneider, 0.1831, NULL, 6057fbdf8c44b900546...
# -RECORD 1---------------------------------------------------------------------------------------------------------------------
#  belongs_to_collection | {87096, Avatar Collection, /3C5brXxnBxfkeKWwA1Fh4xvy4wr.jpg, /6qkJLRCZp9Y3ovXti5tSuhH0DpO.jpg}
#  genres                | [{28, Action}, {12, Adventure}, {14, Fantasy}, {878, Science Fiction}]
#  production_countries  | [{US, United States of America}, {GB, United Kingdom}]
#  production_companies  | [{444, NULL, Dune Entertainment, US}, {574, /8wdmrfGcDx3TJxYiiDksLzAW4pB.png, Lightstorm Entertai...
#  spoken_languages      | [{English, en, English}, {Spanish, es, Español}]
#  origin_country        | [US]
#  cast                  | [{false, 2, 65731, Acting, Sam Worthington, Sam Worthington, 6.4962, /mflBcox36s9ZPbsZPVOuhf6axaJ...
#  crew                  | [{false, 2, 2710, Directing, James Cameron, James Cameron, 4.5563, /9NAZnTjBQ9WcXAQEzZpKy4vdQto.j...
# -RECORD 2---------------------------------------------------------------------------------------------------------------------
#  belongs_to_collection | {10, Star Wars Collection, /22dj38IckjzEEUZwN1tPU5VJ1qq.jpg, /qVPChlozQ1BP3svfHjiAdNneMGA.jpg}
#  genres                | [{12, Adventure}, {28, Action}, {878, Science Fiction}]
#  production_countries  | [{US, United States of America}]
#  production_companies  | [{1, /tlVSws0RvvtPBwViUyOFAO0vcQS.png, Lucasfilm Ltd., US}, {11461, /p9FoEt5shEKRWRKVIlvFaEmRnun....
#  spoken_languages      | [{English, en, English}]
#  origin_country        | [US]
#  cast                  | [{false, 2, 3, Acting, Harrison Ford, Harrison Ford, 4.2236, /5M7oN3sznp99hWYQ9sX0xheswWX.jpg, 8,...
#  crew                  | [{false, 2, 15344, Directing, J.J. Abrams, J.J. Abrams, 2.3808, /uiEVOx3QclxnN76t8PU6v5IcUUP.jpg,...
# only showing top 3 rows

# %%
df.limit(10).toPandas()
# Out:
#    adult                     backdrop_path  \
# 0  False  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg
# 1  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg
# 2  False  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg
# 3  False  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg
# 4  False  /xnHVX37XZEp33hhCbYlQFq7ux1J.jpg
# 5  False  /s5QfDFqRO6sjgPtKkjxD0WqXQef.jpg
# 6  False  /1TUg5pO1VZ4B0Q1amk3OlXvlpXV.jpg
# 7  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 8  False  /ehzI1mVcnHqB58NqPyQwpMqcVoz.jpg
# 9  False  /kIBK5SKwgqIIuRKhhWrJn3XkbPq.jpg
#
#                                belongs_to_collection     budget  \
# 0  (86311, The Avengers Collection, /yFSIUVTCvgYr...  356000000
# 1  (87096, Avatar Collection, /3C5brXxnBxfkeKWwA1...  237000000
# 2  (10, Star Wars Collection, /22dj38IckjzEEUZwN1...  245000000
# 3  (86311, The Avengers Collection, /yFSIUVTCvgYr...  300000000
# 4                                               None  200000000
# 5  (328, Jurassic Park Collection, /qIm2nHXLpBBdM...  150000000
# 6  (762512, The Lion King (Reboot) Collection, /d...  260000000
# 7  (86311, The Avengers Collection, /yFSIUVTCvgYr...  220000000
# 8  (9485, The Fast and the Furious Collection, /z...  190000000
# 9  (86311, The Avengers Collection, /yFSIUVTCvgYr...  235000000
#
#                                               genres  \
# 0  [(12, Adventure), (878, Science Fiction), (28,...
# 1  [(28, Action), (12, Adventure), (14, Fantasy),...
# 2  [(12, Adventure), (28, Action), (878, Science ...
# 3  [(12, Adventure), (28, Action), (878, Science ...
# 4                    [(18, Drama), (10749, Romance)]
# 5  [(28, Action), (12, Adventure), (878, Science ...
# 6  [(12, Adventure), (18, Drama), (10751, Family)...
# 7  [(878, Science Fiction), (28, Action), (12, Ad...
# 8        [(28, Action), (80, Crime), (53, Thriller)]
# 9  [(28, Action), (12, Adventure), (878, Science ...
#
#                                             homepage      id    imdb_id  \
# 0     https://www.marvel.com/movies/avengers-endgame  299534  tt4154796
# 1               https://www.avatar.com/movies/avatar   19995  tt0499549
# 2  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
# 3  https://www.marvel.com/movies/avengers-infinit...  299536  tt4154756
# 4     https://www.paramountmovies.com/movies/titanic     597  tt0120338
# 5                     https://www.jurassicworld.com/  135397  tt0369610
# 6       https://movies.disney.com/the-lion-king-2019  420818  tt6105098
# 7         https://www.marvel.com/movies/the-avengers   24428  tt0848228
# 8              https://www.uphe.com/movies/furious-7  168259  tt2820852
# 9  https://www.marvel.com/movies/avengers-age-of-...   99861  tt2395427
#
#   origin_country original_language  ...     revenue runtime  \
# 0           [US]                en  ...  2799439100     181
# 1           [US]                en  ...  2923706026     162
# 2           [US]                en  ...  2068223624     136
# 3           [US]                en  ...  2052415039     149
# 4           [US]                en  ...  2264162353     194
# 5           [US]                en  ...  1671537444     124
# 6           [US]                en  ...  1662020819     118
# 7           [US]                en  ...  1518815515     143
# 8           [US]                en  ...  1515400000     139
# 9           [US]                en  ...  1405403694     141
#
#                                     spoken_languages    status  \
# 0  [(English, en, English), (Japanese, ja, 日本語), ...  Released
# 1   [(English, en, English), (Spanish, es, Español)]  Released
# 2                           [(English, en, English)]  Released
# 3            [(English, en, English), (Xhosa, xh, )]  Released
# 4  [(English, en, English), (French, fr, Français...  Released
# 5                           [(English, en, English)]  Released
# 6                           [(English, en, English)]  Released
# 7  [(English, en, English), (Hindi, hi, हिन्दी), ...  Released
# 8  [(Arabic, ar, العربية), (English, en, English)...  Released
# 9                           [(English, en, English)]  Released
#
#                                      tagline                         title  \
# 0                         Avenge the fallen.             Avengers: Endgame
# 1                Enter the world of Pandora.                        Avatar
# 2              Every generation has a story.  Star Wars: The Force Awakens
# 3              Destiny arrives all the same.        Avengers: Infinity War
# 4  Nothing on earth could come between them.                       Titanic
# 5                          The park is open.                Jurassic World
# 6                     The king has returned.                 The Lion King
# 7                    Some assembly required.                  The Avengers
# 8                       Vengeance hits home.                     Furious 7
# 9                        A new age has come.       Avengers: Age of Ultron
#
#    video  vote_average  vote_count  \
# 0  False         8.237       27130
# 1  False         7.600       33251
# 2  False         7.254       20200
# 3  False         8.235       31339
# 4  False         7.903       26666
# 5  False         6.700       21219
# 6  False         7.099       10602
# 7  False         7.905       35090
# 8  False         7.219       11089
# 9  False         7.271       24009
#
#                                              credits
# 0  ([(False, 2, 3223, Acting, Robert Downey Jr., ...
# 1  ([(False, 2, 65731, Acting, Sam Worthington, S...
# 2  ([(False, 2, 3, Acting, Harrison Ford, Harriso...
# 3  ([(False, 2, 3223, Acting, Robert Downey Jr., ...
# 4  ([(False, 2, 6193, Acting, Leonardo DiCaprio, ...
# 5  ([(False, 2, 73457, Acting, Chris Pratt, Chris...
# 6  ([(False, 2, 5294, Acting, Chiwetel Ejiofor, C...
# 7  ([(False, 2, 3223, Acting, Robert Downey Jr., ...
# 8  ([(False, 2, 12835, Acting, Vin Diesel, Vin Di...
# 9  ([(False, 2, 3223, Acting, Robert Downey Jr., ...
#
# [10 rows x 27 columns]

# %%
df.columns
# Out:
# ['adult',
#  'backdrop_path',
#  'belongs_to_collection',
#  'budget',
#  'genres',
#  'homepage',
#  'id',
#  'imdb_id',
#  'origin_country',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'revenue',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'video',
#  'vote_average',
#  'vote_count',
#  'credits']

# %% [markdown]
# ## Drop irrelevant columns

# %%
cols_to_drop = ['adult', 'imdb_id', 'original_title', 'video', 'homepage', 	'success', 'status_code', 'status_message']
df = cln.drop_irrelevant_columns(df, cols_to_drop)

# %%
df.toPandas()
# Out:
#                        backdrop_path  \
# 0   /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg
# 1   /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg
# 2   /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg
# 3   /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg
# 4   /xnHVX37XZEp33hhCbYlQFq7ux1J.jpg
# 5   /s5QfDFqRO6sjgPtKkjxD0WqXQef.jpg
# 6   /1TUg5pO1VZ4B0Q1amk3OlXvlpXV.jpg
# 7   /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 8   /ehzI1mVcnHqB58NqPyQwpMqcVoz.jpg
# 9   /kIBK5SKwgqIIuRKhhWrJn3XkbPq.jpg
# 10  /19Ed4XgjahPm4U8JT7SnntERIlt.jpg
# 11  /cbcpDn6XJaIGoOil1bKuskU8ds4.jpg
# 12  /5Iw7zQTHVRBOYpA0V6z0yypOPZh.jpg
# 13  /AoSZyb37ljMAxw0RdeQEBHKtgcc.jpg
# 14  /6WA9stUMbIkEPxn3D5SWlA8FIi7.jpg
# 15  /9WHM084AoskcHCObAy4QnJg01eM.jpg
# 16  /uU1Mt4JWhDvl4vKb3AfxNsorkoM.jpg
# 17  /mabuNsGJgRuCTuGqjFkWe1xdu19.jpg
#
#                                 belongs_to_collection     budget  \
# 0   (86311, The Avengers Collection, /yFSIUVTCvgYr...  356000000
# 1   (87096, Avatar Collection, /3C5brXxnBxfkeKWwA1...  237000000
# 2   (10, Star Wars Collection, /22dj38IckjzEEUZwN1...  245000000
# 3   (86311, The Avengers Collection, /yFSIUVTCvgYr...  300000000
# 4                                                None  200000000
# 5   (328, Jurassic Park Collection, /qIm2nHXLpBBdM...  150000000
# 6   (762512, The Lion King (Reboot) Collection, /d...  260000000
# 7   (86311, The Avengers Collection, /yFSIUVTCvgYr...  220000000
# 8   (9485, The Fast and the Furious Collection, /z...  190000000
# 9   (86311, The Avengers Collection, /yFSIUVTCvgYr...  235000000
# 10  (529892, Black Panther Collection, /VtMkk2s92S...  200000000
# 11  (1241, Harry Potter Collection, /eVPs2Y0LyvTLZ...  125000000
# 12  (10, Star Wars Collection, /22dj38IckjzEEUZwN1...  300000000
# 13  (386382, Frozen Collection, /13Op41T3cALJedrKq...  150000000
# 14  (328, Jurassic Park Collection, /qIm2nHXLpBBdM...  170000000
# 15  (386382, Frozen Collection, /13Op41T3cALJedrKq...  150000000
# 16                                               None  160000000
# 17  (468222, The Incredibles Collection, /iOz4Zz72...  200000000
#
#                                                genres      id origin_country  \
# 0   [(12, Adventure), (878, Science Fiction), (28,...  299534           [US]
# 1   [(28, Action), (12, Adventure), (14, Fantasy),...   19995           [US]
# 2   [(12, Adventure), (28, Action), (878, Science ...  140607           [US]
# 3   [(12, Adventure), (28, Action), (878, Science ...  299536           [US]
# 4                     [(18, Drama), (10749, Romance)]     597           [US]
# 5   [(28, Action), (12, Adventure), (878, Science ...  135397           [US]
# 6   [(12, Adventure), (18, Drama), (10751, Family)...  420818           [US]
# 7   [(878, Science Fiction), (28, Action), (12, Ad...   24428           [US]
# 8         [(28, Action), (80, Crime), (53, Thriller)]  168259           [US]
# 9   [(28, Action), (12, Adventure), (878, Science ...   99861           [US]
# 10  [(28, Action), (12, Adventure), (878, Science ...  284054           [US]
# 11                   [(12, Adventure), (14, Fantasy)]   12445           [GB]
# 12  [(12, Adventure), (28, Action), (878, Science ...  181808           [US]
# 13  [(10751, Family), (16, Animation), (12, Advent...  330457           [US]
# 14  [(28, Action), (12, Adventure), (878, Science ...  351286           [US]
# 15  [(16, Animation), (10751, Family), (12, Advent...  109445           [US]
# 16  [(10751, Family), (14, Fantasy), (10749, Roman...  321612           [US]
# 17  [(28, Action), (12, Adventure), (16, Animation...  260513           [US]
#
#    original_language                                           overview  \
# 0                 en  After the devastating events of Avengers: Infi...
# 1                 en  In the 22nd century, a paraplegic Marine is di...
# 2                 en  Thirty years after defeating the Galactic Empi...
# 3                 en  As the Avengers and their allies have continue...
# 4                 en  101-year-old Rose DeWitt Bukater tells the sto...
# 5                 en  Twenty-two years after the events of Jurassic ...
# 6                 en  Simba idolizes his father, King Mufasa, and ta...
# 7                 en  When an unexpected enemy emerges and threatens...
# 8                 en  Deckard Shaw seeks revenge against Dominic Tor...
# 9                 en  When Tony Stark tries to jumpstart a dormant p...
# 10                en  King T'Challa returns home to the reclusive, t...
# 11                en  Harry, Ron and Hermione continue their quest t...
# 12                en  Rey develops her newly discovered abilities wi...
# 13                en  Elsa, Anna, Kristoff and Olaf head far into th...
# 14                en  Three years after Jurassic World was destroyed...
# 15                en  Young princess Anna of Arendelle dreams about ...
# 16                en  A live-action adaptation of Disney's version o...
# 17                en  Elastigirl springs into action to save the day...
#
#     popularity                       poster_path  ... release_date  \
# 0      19.2389  /bR8ISy1O9XQxqiy0fQFw2BX72RQ.jpg  ...   2019-04-24
# 1      62.8235  /gKY6q7SjCkAU6FqvqWybDYgUKIF.jpg  ...   2009-12-16
# 2      11.1639  /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg  ...   2015-12-15
# 3      28.6259  /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg  ...   2018-04-25
# 4      29.4892  /9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg  ...   1997-12-18
# 5      10.5640  /rhr4y79GpxQF9IsfJItRXVaoGs4.jpg  ...   2015-06-06
# 6       9.8378  /dzBtMocZuJbjLOXvrl4zGYigDzh.jpg  ...   2019-07-12
# 7      65.2961   /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg  ...   2012-04-25
# 8      10.4370  /ktofZ9Htrjiy0P6LEowsDaxd3Ri.jpg  ...   2015-04-01
# 9      17.1821  /4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg  ...   2015-04-22
# 10     13.0709  /uxzzxijgPIY7slzFvMotPv8wjKA.jpg  ...   2018-02-13
# 11     17.3531  /c54HpQmuwXjHq2C9wmoACjxoom3.jpg  ...   2011-07-12
# 12      9.5606  /ySaaKHOLAQU5HoZqWmzDIj1VvZ1.jpg  ...   2017-12-13
# 13      9.8773  /mINJaa34MtknCYl5AjtNJzWj8cD.jpg  ...   2019-11-20
# 14      9.3460  /x2Us3jR6ToMJjbcPbLimYoxf6xr.jpg  ...   2018-06-06
# 15     17.4307  /itAKcobTYGpYT8Phwjd8c9hleTo.jpg  ...   2013-11-20
# 16     13.9711  /hKegSKIDep2ewJWPUQD7u0KqFIp.jpg  ...   2017-03-16
# 17      7.4538  /9lFKBtaVIhP7E2Pk0IY1CwTKTMZ.jpg  ...   2018-06-14
#
#        revenue runtime                                   spoken_languages  \
# 0   2799439100     181  [(English, en, English), (Japanese, ja, 日本語), ...
# 1   2923706026     162   [(English, en, English), (Spanish, es, Español)]
# 2   2068223624     136                           [(English, en, English)]
# 3   2052415039     149            [(English, en, English), (Xhosa, xh, )]
# 4   2264162353     194  [(English, en, English), (French, fr, Français...
# 5   1671537444     124                           [(English, en, English)]
# 6   1662020819     118                           [(English, en, English)]
# 7   1518815515     143  [(English, en, English), (Hindi, hi, हिन्दी), ...
# 8   1515400000     139  [(Arabic, ar, العربية), (English, en, English)...
# 9   1405403694     141                           [(English, en, English)]
# 10  1349926083     135  [(English, en, English), (Korean, ko, 한국어/조선말)...
# 11  1341511219     130                           [(English, en, English)]
# 12  1332698830     152                           [(English, en, English)]
# 13  1453683476     103                           [(English, en, English)]
# 14  1310469037     129   [(English, en, English), (Russian, ru, Pусский)]
# 15  1274219009     102                           [(English, en, English)]
# 16  1266115964     129   [(French, fr, Français), (English, en, English)]
# 17  1243225667     118                           [(English, en, English)]
#
#       status                                            tagline  \
# 0   Released                                 Avenge the fallen.
# 1   Released                        Enter the world of Pandora.
# 2   Released                      Every generation has a story.
# 3   Released                      Destiny arrives all the same.
# 4   Released          Nothing on earth could come between them.
# 5   Released                                  The park is open.
# 6   Released                             The king has returned.
# 7   Released                            Some assembly required.
# 8   Released                               Vengeance hits home.
# 9   Released                                A new age has come.
# 10  Released                                Long live the king.
# 11  Released                                       It all ends.
# 12  Released                                  Let the past die.
# 13  Released                     The past is not what it seems.
# 14  Released                                  The park is gone.
# 15  Released  Who will save the day? The ice guy? The nice g...
# 16  Released                                      Be our guest.
# 17  Released                      It's been too long, dahlings.
#
#                                            title vote_average vote_count  \
# 0                              Avengers: Endgame        8.237      27130
# 1                                         Avatar        7.600      33251
# 2                   Star Wars: The Force Awakens        7.254      20200
# 3                         Avengers: Infinity War        8.235      31339
# 4                                        Titanic        7.903      26666
# 5                                 Jurassic World        6.700      21219
# 6                                  The Lion King        7.099      10602
# 7                                   The Avengers        7.905      35090
# 8                                      Furious 7        7.219      11089
# 9                        Avengers: Age of Ultron        7.271      24009
# 10                                 Black Panther        7.364      23078
# 11  Harry Potter and the Deathly Hallows: Part 2        8.082      21574
# 12                      Star Wars: The Last Jedi        6.762      16018
# 13                                     Frozen II        7.238      10119
# 14                Jurassic World: Fallen Kingdom        6.535      12484
# 15                                        Frozen        7.248      17275
# 16                          Beauty and the Beast        6.969      15877
# 17                                 Incredibles 2        7.454      13443
#
#                                               credits
# 0   ([(False, 2, 3223, Acting, Robert Downey Jr., ...
# 1   ([(False, 2, 65731, Acting, Sam Worthington, S...
# 2   ([(False, 2, 3, Acting, Harrison Ford, Harriso...
# 3   ([(False, 2, 3223, Acting, Robert Downey Jr., ...
# 4   ([(False, 2, 6193, Acting, Leonardo DiCaprio, ...
# 5   ([(False, 2, 73457, Acting, Chris Pratt, Chris...
# 6   ([(False, 2, 5294, Acting, Chiwetel Ejiofor, C...
# 7   ([(False, 2, 3223, Acting, Robert Downey Jr., ...
# 8   ([(False, 2, 12835, Acting, Vin Diesel, Vin Di...
# 9   ([(False, 2, 3223, Acting, Robert Downey Jr., ...
# 10  ([(False, 2, 172069, Acting, Chadwick Boseman,...
# 11  ([(False, 2, 10980, Acting, Daniel Radcliffe, ...
# 12  ([(False, 2, 2, Acting, Mark Hamill, Mark Hami...
# 13  ([(False, 1, 19394, Acting, Idina Menzel, Idin...
# 14  ([(False, 2, 73457, Acting, Chris Pratt, Chris...
# 15  ([(False, 1, 19394, Acting, Idina Menzel, Idin...
# 16  ([(False, 1, 10990, Acting, Emma Watson, Emma ...
# 17  ([(False, 2, 8977, Acting, Craig T. Nelson, Cr...
#
# [18 rows x 22 columns]

# %%
df.columns
# Out:
# ['backdrop_path',
#  'belongs_to_collection',
#  'budget',
#  'genres',
#  'id',
#  'origin_country',
#  'original_language',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'revenue',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'vote_average',
#  'vote_count',
#  'credits']

# %% [markdown]
# ## Evaluate JSON-like columns

# %%
categorical_columns = ['belongs_to_collection', 'genres', 'production_countries', 'production_companies', 'spoken_languages', 'origin_country','credits']

# %%
df.select(*categorical_columns).limit(10).toPandas()
# Out:
#                                belongs_to_collection  \
# 0  (86311, The Avengers Collection, /yFSIUVTCvgYr...
# 1  (87096, Avatar Collection, /3C5brXxnBxfkeKWwA1...
# 2  (10, Star Wars Collection, /22dj38IckjzEEUZwN1...
# 3  (86311, The Avengers Collection, /yFSIUVTCvgYr...
# 4                                               None
# 5  (328, Jurassic Park Collection, /qIm2nHXLpBBdM...
# 6  (762512, The Lion King (Reboot) Collection, /d...
# 7  (86311, The Avengers Collection, /yFSIUVTCvgYr...
# 8  (9485, The Fast and the Furious Collection, /z...
# 9  (86311, The Avengers Collection, /yFSIUVTCvgYr...
#
#                                               genres  \
# 0  [(12, Adventure), (878, Science Fiction), (28,...
# 1  [(28, Action), (12, Adventure), (14, Fantasy),...
# 2  [(12, Adventure), (28, Action), (878, Science ...
# 3  [(12, Adventure), (28, Action), (878, Science ...
# 4                    [(18, Drama), (10749, Romance)]
# 5  [(28, Action), (12, Adventure), (878, Science ...
# 6  [(12, Adventure), (18, Drama), (10751, Family)...
# 7  [(878, Science Fiction), (28, Action), (12, Ad...
# 8        [(28, Action), (80, Crime), (53, Thriller)]
# 9  [(28, Action), (12, Adventure), (878, Science ...
#
#                                 production_countries  \
# 0                   [(US, United States of America)]
# 1  [(US, United States of America), (GB, United K...
# 2                   [(US, United States of America)]
# 3                   [(US, United States of America)]
# 4                   [(US, United States of America)]
# 5                   [(US, United States of America)]
# 6                   [(US, United States of America)]
# 7                   [(US, United States of America)]
# 8                   [(US, United States of America)]
# 9                   [(US, United States of America)]
#
#                                 production_companies  \
# 0  [(420, /hUzeosd33nzE5MCNsZxCGEKTXaQ.png, Marve...
# 1  [(444, None, Dune Entertainment, US), (574, /8...
# 2  [(1, /tlVSws0RvvtPBwViUyOFAO0vcQS.png, Lucasfi...
# 3  [(420, /hUzeosd33nzE5MCNsZxCGEKTXaQ.png, Marve...
# 4  [(4, /jay6WcMgagAklUt7i9Euwj1pzTF.png, Paramou...
# 5  [(56, /cEaxANEisCqeEoRvODv2dO1I0iI.png, Amblin...
# 6  [(2, /wdrCwmRnLFJhEoH8GSfymY85KHT.png, Walt Di...
# 7  [(420, /hUzeosd33nzE5MCNsZxCGEKTXaQ.png, Marve...
# 8  [(333, /5xUJfzPZ8jWJUDzYtIeuPO4qPIa.png, Origi...
# 9  [(420, /hUzeosd33nzE5MCNsZxCGEKTXaQ.png, Marve...
#
#                                     spoken_languages origin_country  \
# 0  [(English, en, English), (Japanese, ja, 日本語), ...           [US]
# 1   [(English, en, English), (Spanish, es, Español)]           [US]
# 2                           [(English, en, English)]           [US]
# 3            [(English, en, English), (Xhosa, xh, )]           [US]
# 4  [(English, en, English), (French, fr, Français...           [US]
# 5                           [(English, en, English)]           [US]
# 6                           [(English, en, English)]           [US]
# 7  [(English, en, English), (Hindi, hi, हिन्दी), ...           [US]
# 8  [(Arabic, ar, العربية), (English, en, English)...           [US]
# 9                           [(English, en, English)]           [US]
#
#                                              credits
# 0  ([(False, 2, 3223, Acting, Robert Downey Jr., ...
# 1  ([(False, 2, 65731, Acting, Sam Worthington, S...
# 2  ([(False, 2, 3, Acting, Harrison Ford, Harriso...
# 3  ([(False, 2, 3223, Acting, Robert Downey Jr., ...
# 4  ([(False, 2, 6193, Acting, Leonardo DiCaprio, ...
# 5  ([(False, 2, 73457, Acting, Chris Pratt, Chris...
# 6  ([(False, 2, 5294, Acting, Chiwetel Ejiofor, C...
# 7  ([(False, 2, 3223, Acting, Robert Downey Jr., ...
# 8  ([(False, 2, 12835, Acting, Vin Diesel, Vin Di...
# 9  ([(False, 2, 3223, Acting, Robert Downey Jr., ...

# %% [markdown]
# ## Extracting and cleaning json columns

# %%
df = cln.clean_movie_data(df)

# %%
df.limit(10).toPandas()
# Out:
#                       backdrop_path                belongs_to_collection  \
# 0  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg              The Avengers Collection
# 1  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg                    Avatar Collection
# 2  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg                 Star Wars Collection
# 3  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg              The Avengers Collection
# 4  /xnHVX37XZEp33hhCbYlQFq7ux1J.jpg                                 None
# 5  /s5QfDFqRO6sjgPtKkjxD0WqXQef.jpg             Jurassic Park Collection
# 6  /1TUg5pO1VZ4B0Q1amk3OlXvlpXV.jpg    The Lion King (Reboot) Collection
# 7  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg              The Avengers Collection
# 8  /ehzI1mVcnHqB58NqPyQwpMqcVoz.jpg  The Fast and the Furious Collection
# 9  /kIBK5SKwgqIIuRKhhWrJn3XkbPq.jpg              The Avengers Collection
#
#         budget                                     genres        id  \
# 0  356000000.0           Adventure|Science Fiction|Action  299534.0
# 1  237000000.0   Action|Adventure|Fantasy|Science Fiction   19995.0
# 2  245000000.0           Adventure|Action|Science Fiction  140607.0
# 3  300000000.0           Adventure|Action|Science Fiction  299536.0
# 4  200000000.0                              Drama|Romance     597.0
# 5  150000000.0  Action|Adventure|Science Fiction|Thriller  135397.0
# 6  260000000.0           Adventure|Drama|Family|Animation  420818.0
# 7  220000000.0           Science Fiction|Action|Adventure   24428.0
# 8  190000000.0                      Action|Crime|Thriller  168259.0
# 9  235000000.0           Action|Adventure|Science Fiction   99861.0
#
#   origin_country original_language  \
# 0             US                en
# 1             US                en
# 2             US                en
# 3             US                en
# 4             US                en
# 5             US                en
# 6             US                en
# 7             US                en
# 8             US                en
# 9             US                en
#
#                                             overview  popularity  \
# 0  After the devastating events of Avengers: Infi...     19.2389
# 1  In the 22nd century, a paraplegic Marine is di...     62.8235
# 2  Thirty years after defeating the Galactic Empi...     11.1639
# 3  As the Avengers and their allies have continue...     28.6259
# 4  101-year-old Rose DeWitt Bukater tells the sto...     29.4892
# 5  Twenty-two years after the events of Jurassic ...     10.5640
# 6  Simba idolizes his father, King Mufasa, and ta...      9.8378
# 7  When an unexpected enemy emerges and threatens...     65.2961
# 8  Deckard Shaw seeks revenge against Dominic Tor...     10.4370
# 9  When Tony Stark tries to jumpstart a dormant p...     17.1821
#
#                         poster_path  ...  \
# 0  /bR8ISy1O9XQxqiy0fQFw2BX72RQ.jpg  ...
# 1  /gKY6q7SjCkAU6FqvqWybDYgUKIF.jpg  ...
# 2  /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg  ...
# 3  /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg  ...
# 4  /9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg  ...
# 5  /rhr4y79GpxQF9IsfJItRXVaoGs4.jpg  ...
# 6  /dzBtMocZuJbjLOXvrl4zGYigDzh.jpg  ...
# 7   /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg  ...
# 8  /ktofZ9Htrjiy0P6LEowsDaxd3Ri.jpg  ...
# 9  /4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg  ...
#
#                                 spoken_languages    status  \
# 0                         English|Japanese|Xhosa  Released
# 1                                English|Spanish  Released
# 2                                        English  Released
# 3                                  English|Xhosa  Released
# 4  English|French|German|Swedish|Italian|Russian  Released
# 5                                        English  Released
# 6                                        English  Released
# 7                          English|Hindi|Russian  Released
# 8                    Arabic|English|Spanish|Thai  Released
# 9                                        English  Released
#
#                                      tagline                         title  \
# 0                         Avenge the fallen.             Avengers: Endgame
# 1                Enter the world of Pandora.                        Avatar
# 2              Every generation has a story.  Star Wars: The Force Awakens
# 3              Destiny arrives all the same.        Avengers: Infinity War
# 4  Nothing on earth could come between them.                       Titanic
# 5                          The park is open.                Jurassic World
# 6                     The king has returned.                 The Lion King
# 7                    Some assembly required.                  The Avengers
# 8                       Vengeance hits home.                     Furious 7
# 9                        A new age has come.       Avengers: Age of Ultron
#
#    vote_average vote_count                                               cast  \
# 0         8.237    27130.0  Robert Downey Jr.|Chris Evans|Mark Ruffalo|Chr...
# 1         7.600    33251.0  Sam Worthington|Zoe Saldaña|Sigourney Weaver|S...
# 2         7.254    20200.0  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 3         8.235    31339.0  Robert Downey Jr.|Chris Evans|Chris Hemsworth|...
# 4         7.903    26666.0  Leonardo DiCaprio|Kate Winslet|Billy Zane|Kath...
# 5         6.700    21219.0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 6         7.099    10602.0  Chiwetel Ejiofor|John Oliver|Donald Glover|Jam...
# 7         7.905    35090.0  Robert Downey Jr.|Chris Evans|Mark Ruffalo|Chr...
# 8         7.219    11089.0  Vin Diesel|Paul Walker|Dwayne Johnson|Michelle...
# 9         7.271    24009.0  Robert Downey Jr.|Chris Hemsworth|Mark Ruffalo...
#
#   cast_size                 director  crew_size
# 0       107  Anthony Russo|Joe Russo        608
# 1        67            James Cameron        991
# 2       183              J.J. Abrams        264
# 3        69  Joe Russo|Anthony Russo        734
# 4       116            James Cameron        262
# 5        53          Colin Trevorrow        428
# 6        20              Jon Favreau         50
# 7       113              Joss Whedon        642
# 8        49                James Wan        228
# 9        74              Joss Whedon        653
#
# [10 rows x 25 columns]

# %%
df.dtypes
# Out:
# [('backdrop_path', 'string'),
#  ('belongs_to_collection', 'string'),
#  ('budget', 'double'),
#  ('genres', 'string'),
#  ('id', 'double'),
#  ('origin_country', 'string'),
#  ('original_language', 'string'),
#  ('overview', 'string'),
#  ('popularity', 'double'),
#  ('poster_path', 'string'),
#  ('production_companies', 'string'),
#  ('production_countries', 'string'),
#  ('release_date', 'date'),
#  ('revenue', 'double'),
#  ('runtime', 'double'),
#  ('spoken_languages', 'string'),
#  ('status', 'string'),
#  ('tagline', 'string'),
#  ('title', 'string'),
#  ('vote_average', 'double'),
#  ('vote_count', 'double'),
#  ('cast', 'string'),
#  ('cast_size', 'int'),
#  ('director', 'string'),
#  ('crew_size', 'int')]

# %%
# 1) quick overview
show_schema_overview(df)

# 2) get extractor suggestions
suggest_extractors(df)

# 3) explore a specific map col (e.g. belongs_to_collection)
explore_map_column(df, "belongs_to_collection")

# 4) explore an array of maps (e.g. genres or production_companies)
explore_array_column(df, "genres")

# 5) safely apply an extractor only when schema matches
df2 = safe_apply_array_map_extractor(df, "genres", "name", out_col="genres_names")

# 6) run a full exploration of nested columns (be careful on very large datasets)
explore_all_nested(df, sample_limit=5)
# Out:
# Column | SparkType | Nested?
# backdrop_path | string | False
# belongs_to_collection | map<string,bigint> | True
# budget | bigint | False
# credits | map<string,array<map<string,boolean>>> | True
# genres | array<map<string,bigint>> | True
# id | bigint | False
# origin_country | array<string> | True
# original_language | string | False
# overview | string | False
# popularity | double | False
# poster_path | string | False
# production_companies | array<map<string,bigint>> | True
# production_countries | array<map<string,string>> | True
# release_date | string | False
# revenue | bigint | False
# runtime | bigint | False
# spoken_languages | array<map<string,string>> | True
# status | string | False
# tagline | string | False
# title | string | False
# vote_average | double | False
# vote_count | bigint | False
# backdrop_path                  : SCALAR -> leave or cast
# belongs_to_collection          : MAP -> use col.getItem(key) or explode(map_entries(col))
# budget                         : SCALAR -> leave or cast
# credits                        : MAP -> use col.getItem(key) or explode(map_entries(col))
# genres                         : ARRAY<MAP> -> explode/transform then extract map keys (x['name'])
# id                             : SCALAR -> leave or cast
# origin_country                 : ARRAY<STRING> -> concat_ws(join_with, col)
# original_language              : SCALAR -> leave or cast
# overview                       : SCALAR -> leave or cast
# popularity                     : SCALAR -> leave or cast
# poster_path                    : SCALAR -> leave or cast
# production_companies           : ARRAY<MAP> -> explode/transform then extract map keys (x['name'])
# production_countries           : ARRAY<MAP> -> explode/transform then extract map keys (x['name'])
# release_date                   : SCALAR -> leave or cast
# revenue                        : SCALAR -> leave or cast
# runtime                        : SCALAR -> leave or cast
# spoken_languages               : ARRAY<MAP> -> explode/transform then extract map keys (x['name'])
# status                         : SCALAR -> leave or cast
# tagline                        : SCALAR -> leave or cast
# title                          : SCALAR -> leave or cast
# vote_average                   : SCALAR -> leave or cast
# vote_count                     : SCALAR -> leave or cast
# Exploring MAP column 'belongs_to_collection'
# Non-null rows: 16
# Top keys (key, count):
# +-------------+-----+
# |key          |count|
# +-------------+-----+
# |name         |16   |
# |poster_path  |16   |
# |backdrop_path|16   |
# |id           |16   |
# +-------------+-----+
#
# Key + observed value types + counts:
# +-------------+----------+-----+
# |key          |value_type|count|
# +-------------+----------+-----+
# |poster_path  |bigint    |16   |
# |id           |bigint    |16   |
# |backdrop_path|bigint    |16   |
# |name         |bigint    |16   |
# +-------------+----------+-----+
#
# Sample raw map (first 5 non-null rows):
# +-----------------------------------------------------------------------+
# |belongs_to_collection                                                  |
# +-----------------------------------------------------------------------+
# |{backdrop_path -> NULL, name -> NULL, id -> 86311, poster_path -> NULL}|
# |{backdrop_path -> NULL, name -> NULL, id -> 87096, poster_path -> NULL}|
# |{backdrop_path -> NULL, name -> NULL, id -> 10, poster_path -> NULL}   |
# |{backdrop_path -> NULL, name -> NULL, id -> 86311, poster_path -> NULL}|
# |{backdrop_path -> NULL, name -> NULL, id -> 328, poster_path -> NULL}  |
# +-----------------------------------------------------------------------+
#
# Exploring ARRAY column 'genres'
# Non-null rows: 18
# Observed element types (elem_type, count):
# +------------------+-----+
# |elem_type         |count|
# +------------------+-----+
# |map<string,bigint>|60   |
# +------------------+-----+
#
# No map elements observed (or unable to detect).
# No struct elements observed (or unable to detect).
# Sample exploded elements (limit 10):
# +-------------------------+
# |elem                     |
# +-------------------------+
# |{name -> NULL, id -> 12} |
# |{name -> NULL, id -> 878}|
# |{name -> NULL, id -> 28} |
# |{name -> NULL, id -> 28} |
# |{name -> NULL, id -> 12} |
# |{name -> NULL, id -> 14} |
# |{name -> NULL, id -> 878}|
# |{name -> NULL, id -> 12} |
# |{name -> NULL, id -> 28} |
# |{name -> NULL, id -> 878}|
# +-------------------------+
#
# === SCHEMA OVERVIEW ===
# Column | SparkType | Nested?
# backdrop_path | string | False
# belongs_to_collection | map<string,bigint> | True
# budget | bigint | False
# credits | map<string,array<map<string,boolean>>> | True
# genres | array<map<string,bigint>> | True
# id | bigint | False
# origin_country | array<string> | True
# original_language | string | False
# overview | string | False
# popularity | double | False
# poster_path | string | False
# production_companies | array<map<string,bigint>> | True
# production_countries | array<map<string,string>> | True
# release_date | string | False
# revenue | bigint | False
# runtime | bigint | False
# spoken_languages | array<map<string,string>> | True
# status | string | False
# tagline | string | False
# title | string | False
# vote_average | double | False
# vote_count | bigint | False
#
# === SUGGESTED EXTRACTORS ===
# backdrop_path                  : SCALAR -> leave or cast
# belongs_to_collection          : MAP -> use col.getItem(key) or explode(map_entries(col))
# budget                         : SCALAR -> leave or cast
# credits                        : MAP -> use col.getItem(key) or explode(map_entries(col))
# genres                         : ARRAY<MAP> -> explode/transform then extract map keys (x['name'])
# id                             : SCALAR -> leave or cast
# origin_country                 : ARRAY<STRING> -> concat_ws(join_with, col)
# original_language              : SCALAR -> leave or cast
# overview                       : SCALAR -> leave or cast
# popularity                     : SCALAR -> leave or cast
# poster_path                    : SCALAR -> leave or cast
# production_companies           : ARRAY<MAP> -> explode/transform then extract map keys (x['name'])
# production_countries           : ARRAY<MAP> -> explode/transform then extract map keys (x['name'])
# release_date                   : SCALAR -> leave or cast
# revenue                        : SCALAR -> leave or cast
# runtime                        : SCALAR -> leave or cast
# spoken_languages               : ARRAY<MAP> -> explode/transform then extract map keys (x['name'])
# status                         : SCALAR -> leave or cast
# tagline                        : SCALAR -> leave or cast
# title                          : SCALAR -> leave or cast
# vote_average                   : SCALAR -> leave or cast
# vote_count                     : SCALAR -> leave or cast
#
# ----------------------------------------
# Exploring MAP column 'belongs_to_collection'
# Non-null rows: 16
# Top keys (key, count):
# +-------------+-----+
# |key          |count|
# +-------------+-----+
# |backdrop_path|16   |
# |name         |16   |
# |id           |16   |
# |poster_path  |16   |
# +-------------+-----+
#
# Key + observed value types + counts:
# +-------------+----------+-----+
# |key          |value_type|count|
# +-------------+----------+-----+
# |backdrop_path|bigint    |16   |
# |name         |bigint    |16   |
# |id           |bigint    |16   |
# |poster_path  |bigint    |16   |
# +-------------+----------+-----+
#
# Sample raw map (first 5 non-null rows):
# +-----------------------------------------------------------------------+
# |belongs_to_collection                                                  |
# +-----------------------------------------------------------------------+
# |{backdrop_path -> NULL, name -> NULL, id -> 86311, poster_path -> NULL}|
# |{backdrop_path -> NULL, name -> NULL, id -> 87096, poster_path -> NULL}|
# |{backdrop_path -> NULL, name -> NULL, id -> 10, poster_path -> NULL}   |
# |{backdrop_path -> NULL, name -> NULL, id -> 86311, poster_path -> NULL}|
# |{backdrop_path -> NULL, name -> NULL, id -> 328, poster_path -> NULL}  |
# +-----------------------------------------------------------------------+
#
#
# ----------------------------------------
# Exploring MAP column 'credits'
# Non-null rows: 18
# Top keys (key, count):
# +----+-----+
# |key |count|
# +----+-----+
# |cast|18   |
# |crew|18   |
# +----+-----+
#
# Key + observed value types + counts:
# +----+--------------------------+-----+
# |key |value_type                |count|
# +----+--------------------------+-----+
# |cast|array<map<string,boolean>>|18   |
# |crew|array<map<string,boolean>>|18   |
# +----+--------------------------+-----+
#
# Sample raw map (first 5 non-null rows):
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |credits                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |{cast -> [{cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NUL ...
# |{cast -> [{cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NUL ...
# |{cast -> [{cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NUL ...
# |{cast -> [{cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NUL ...
# |{cast -> [{cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NULL, name -> NULL, id -> NULL, adult -> false, order -> NULL}, {cast_id -> NULL, gender -> NULL, known_for_department -> NULL, profile_path -> NULL, character -> NULL, credit_id -> NULL, popularity -> NULL, original_name -> NUL ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
#
#
# ----------------------------------------
# Exploring ARRAY column 'genres'
# Non-null rows: 18
# Observed element types (elem_type, count):
# +------------------+-----+
# |elem_type         |count|
# +------------------+-----+
# |map<string,bigint>|60   |
# +------------------+-----+
#
# No map elements observed (or unable to detect).
# No struct elements observed (or unable to detect).
# Sample exploded elements (limit 10):
# +-------------------------+
# |elem                     |
# +-------------------------+
# |{name -> NULL, id -> 12} |
# |{name -> NULL, id -> 878}|
# |{name -> NULL, id -> 28} |
# |{name -> NULL, id -> 28} |
# |{name -> NULL, id -> 12} |
# |{name -> NULL, id -> 14} |
# |{name -> NULL, id -> 878}|
# |{name -> NULL, id -> 12} |
# |{name -> NULL, id -> 28} |
# |{name -> NULL, id -> 878}|
# +-------------------------+
#
#
# ----------------------------------------
# Exploring ARRAY column 'origin_country'
# Non-null rows: 18
# Observed element types (elem_type, count):
# +---------+-----+
# |elem_type|count|
# +---------+-----+
# |string   |18   |
# +---------+-----+
#
# Error exploring origin_country: [DATATYPE_MISMATCH.UNEXPECTED_INPUT_TYPE] Cannot resolve "map_keys(elem)" due to data type mismatch: Parameter 1 requires the "MAP" type, however "elem" has the type "STRING".;
# 'Project [map_keys(elem#594) AS keys#616]
# +- Filter (typeof(elem#594) = map)
#    +- Project [elem#594]
#       +- Generate explode(origin_country#9), false, [elem#594]
#          +- GlobalLimit 100
#             +- LocalLimit 100
#                +- Project [origin_country#9]
#                   +- Project [backdrop_path#1, belongs_to_collection#2, budget#3L, credits#4, genres#5, id#7L, origin_country#9, original_language#10, overview#12, popularity#13, poster_path#14, production_companies#15, production_countries#16, release_date#17, revenue#18L, runtime#19L, spoken_languages#20, status#21, tagline#22, title#23, vote_average#25, vote_count#26L]
#                      +- LogicalRDD [adult#0, backdrop_path#1, belongs_to_collection#2, budget#3L, credits#4, genres#5, homepage#6, id#7L, imdb_id#8, origin_country#9, original_language#10, original_title#11, overview#12, popularity#13, poster_path#14, production_companies#15, production_countries#16, release_date#17, revenue#18L, runtime#19L, spoken_languages#20, status#21, tagline#22, title#23, ... 3 more fields], false
#
#
# ----------------------------------------
# Exploring ARRAY column 'production_companies'
# Non-null rows: 18
# Observed element types (elem_type, count):
# +------------------+-----+
# |elem_type         |count|
# +------------------+-----+
# |map<string,bigint>|32   |
# +------------------+-----+
#
# No map elements observed (or unable to detect).
# No struct elements observed (or unable to detect).
# Sample exploded elements (limit 10):
# +-----------------------------------------------------------------------+
# |elem                                                                   |
# +-----------------------------------------------------------------------+
# |{name -> NULL, id -> 420, logo_path -> NULL, origin_country -> NULL}   |
# |{name -> NULL, id -> 444, logo_path -> NULL, origin_country -> NULL}   |
# |{name -> NULL, id -> 574, logo_path -> NULL, origin_country -> NULL}   |
# |{name -> NULL, id -> 25, logo_path -> NULL, origin_country -> NULL}    |
# |{name -> NULL, id -> 133789, logo_path -> NULL, origin_country -> NULL}|
# |{name -> NULL, id -> 1, logo_path -> NULL, origin_country -> NULL}     |
# |{name -> NULL, id -> 11461, logo_path -> NULL, origin_country -> NULL} |
# |{name -> NULL, id -> 420, logo_path -> NULL, origin_country -> NULL}   |
# |{name -> NULL, id -> 4, logo_path -> NULL, origin_country -> NULL}     |
# |{name -> NULL, id -> 25, logo_path -> NULL, origin_country -> NULL}    |
# +-----------------------------------------------------------------------+
#
#
# ----------------------------------------
# Exploring ARRAY column 'production_countries'
# Non-null rows: 18
# Observed element types (elem_type, count):
# +------------------+-----+
# |elem_type         |count|
# +------------------+-----+
# |map<string,string>|20   |
# +------------------+-----+
#
# No map elements observed (or unable to detect).
# No struct elements observed (or unable to detect).
# Sample exploded elements (limit 10):
# +----------------------------------------------------+
# |elem                                                |
# +----------------------------------------------------+
# |{name -> United States of America, iso_3166_1 -> US}|
# |{name -> United States of America, iso_3166_1 -> US}|
# |{name -> United Kingdom, iso_3166_1 -> GB}          |
# |{name -> United States of America, iso_3166_1 -> US}|
# |{name -> United States of America, iso_3166_1 -> US}|
# |{name -> United States of America, iso_3166_1 -> US}|
# |{name -> United States of America, iso_3166_1 -> US}|
# |{name -> United States of America, iso_3166_1 -> US}|
# |{name -> United States of America, iso_3166_1 -> US}|
# |{name -> United States of America, iso_3166_1 -> US}|
# +----------------------------------------------------+
#
#
# ----------------------------------------
# Exploring ARRAY column 'spoken_languages'
# Non-null rows: 18
# Observed element types (elem_type, count):
# +------------------+-----+
# |elem_type         |count|
# +------------------+-----+
# |map<string,string>|37   |
# +------------------+-----+
#
# No map elements observed (or unable to detect).
# No struct elements observed (or unable to detect).
# Sample exploded elements (limit 10):
# +-----------------------------------------------------------+
# |elem                                                       |
# +-----------------------------------------------------------+
# |{name -> English, iso_639_1 -> en, english_name -> English}|
# |{name -> 日本語, iso_639_1 -> ja, english_name -> Japanese}|
# |{name -> , iso_639_1 -> xh, english_name -> Xhosa}         |
# |{name -> English, iso_639_1 -> en, english_name -> English}|
# |{name -> Español, iso_639_1 -> es, english_name -> Spanish}|
# |{name -> English, iso_639_1 -> en, english_name -> English}|
# |{name -> English, iso_639_1 -> en, english_name -> English}|
# |{name -> , iso_639_1 -> xh, english_name -> Xhosa}         |
# |{name -> English, iso_639_1 -> en, english_name -> English}|
# |{name -> Français, iso_639_1 -> fr, english_name -> French}|
# +-----------------------------------------------------------+
